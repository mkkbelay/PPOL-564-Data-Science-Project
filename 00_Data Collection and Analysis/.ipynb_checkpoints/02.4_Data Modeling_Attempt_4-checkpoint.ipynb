# %%
##import packages to be used in this session
import pandas as pd
from pandas.api.types import CategoricalDtype # Ordering categories
import numpy as np
import missingno as miss
import math

# Plotting libraries
from plotnine import *
import matplotlib.pyplot as plt

# For pre-processing data 
from sklearn import preprocessing as pp 
from sklearn.compose import ColumnTransformer 

# For splits and CV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold # Cross validation 
from sklearn.model_selection import cross_validate # Cross validation 
from sklearn.model_selection import GridSearchCV # Cross validation + param. tuning.

# Machine learning methods 
# Machine learning methods 
from sklearn.linear_model import LinearRegression as LM
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.tree import DecisionTreeRegressor as DTree
from sklearn import tree # For plotting the decision tree rules
from sklearn.ensemble import BaggingRegressor as Bag
from sklearn.ensemble import RandomForestRegressor as RF
from sklearn.impute import SimpleImputer

# For evaluating our model's performance
import sklearn.metrics as m

# Pipeline to combine modeling elements
from sklearn.pipeline import Pipeline

# Misc
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# This attempt will use the same data set as attempt 3. However, there will be modifications regarding variable selection; pre-processing; and the creation of the outcome variable. The last attempt showed that using more features along with a modified outcome variable tracking disparity for a single race reduced the mean squared error substantially. This final attempt will build on that information by creating five separate outcome variables and conducting five iterations of the modeling and interpretation process. Also, unlike the previous attempts, imputing will be used to address missingness. Additionally, the correlation between the features will be considered when selecting variables for the predictive model.
#
# Additionally, unlike the previous attempts, the scoring metric will be root mean squared error rather than mean squared error. As pointed out in the feedback I recieved in my presentation, the root mean squared error is easier to interpret.
#
# Lastly, this attempt will use only three (Linear Model, KNN, and Random Forest) out of the five models used in previous attempts. From the previous attempts, the decision tree continually preformed the worst, so it will be excluded. Although bagging was doing well, it will be excluded because the underlying process it uses to make predictions is kind of similar to Random Forest (i.e., bootstrapping statistical technique of randomly taking samples). And the Random Forest performed the best.

# %%
##import project csv file
df=pd.read_csv("Data/COVID_project_PPOL564_v2.csv")

# %%
##print shape
df.shape
# Out:
# (974, 46)

# %%
##view first 10 observations
df.head(10)
# Out:
#    fips state           county  cases  white_cases  black_cases  \
# 0  1001    AL   Autauga County    119           44           21
# 1  1003    AL   Baldwin County    201          144            6
# 2  1005    AL   Barbour County     91            5           32
# 3  1007    AL      Bibb County     50           17            5
# 4  1009    AL    Blount County     37           15            0
# 5  1011    AL   Bullock County    125            0          106
# 6  1013    AL    Butler County    263           65          166
# 7  1015    AL   Calhoun County    124           72           23
# 8  1017    AL  Chambers County    301           81          181
# 9  1021    AL   Chilton County     65           27            0
#
#    hispanic_cases  native_cases  asian_cases  TOT_POP  ...  perc_plumb  \
# 0               0             0            0    55869  ...    0.013462
# 1               0             0            0   223234  ...    0.004790
# 2               0             0            0    24686  ...    0.006031
# 3               0             0            0    22394  ...    0.007092
# 4               0             0            0    57826  ...    0.010912
# 5               0             0            0    10101  ...    0.030942
# 6               0             0            0    19448  ...    0.003909
# 7               0             0            0   113605  ...    0.008431
# 8               0             0            0    33254  ...    0.009386
# 9               0             0            0    44428  ...    0.008123
#
#    lng_commute   life_exp  pre_mortality  phys_distress  ment_distress  \
# 0        0.396  76.879477     417.547551       0.136852       0.141293
# 1        0.417  78.450258     353.343111       0.124801       0.134753
# 2        0.322  75.341935     497.350062       0.171849       0.165863
# 3        0.498  73.571820     589.041117       0.136266       0.140175
# 4        0.594  74.145826     515.611823       0.145232       0.148593
# 5        0.460  73.530895     562.247530       0.168810       0.158548
# 6        0.323  72.918309     609.169707       0.166967       0.169154
# 7        0.312  73.039109     574.563842       0.147544       0.151915
# 8        0.318  74.291076     511.626517       0.152478       0.154967
# 9        0.503  74.926751     519.630806       0.145910       0.151771
#
#    diab_prevalence food_insecure  food_access  perc_rural
# 0            0.111         0.132     0.119911    0.420022
# 1            0.107         0.116     0.054244    0.422791
# 2            0.176         0.220     0.107397    0.677896
# 3            0.145         0.143     0.026016    0.683526
# 4            0.170         0.107     0.028801    0.899515
# 5            0.237         0.248     0.197434    0.513744
# 6            0.192         0.206     0.029261    0.712322
# 7            0.175         0.157     0.091786    0.336968
# 8            0.199         0.179     0.103286    0.491480
# 9            0.186         0.131     0.014605    0.867447
#
# [10 rows x 46 columns]

# %% [markdown]
# We'll start by examining the data types and making adjustments to prepare for visualization and take notes for high-level pre-processing.

# %%
##check data types
df.dtypes
# Out:
# fips                   int64
# state                 object
# county                object
# cases                  int64
# white_cases            int64
# black_cases            int64
# hispanic_cases         int64
# native_cases           int64
# asian_cases            int64
# TOT_POP                int64
# WH                     int64
# BA                     int64
# AA                     int64
# IA                     int64
# HI                     int64
# GDP                  float64
# pov_perc             float64
# Med_inc               object
# Unemployment Rate    float64
# traffic_vol          float64
# house_burden         float64
# ownership            float64
# residential_seg      float64
# food_index           float64
# pop_to_phys          float64
# water_violation      float64
# air_pollution        float64
# uninsured            float64
# exercise_opp         float64
# income_ineq          float64
# crime_violent        float64
# high_sch_grad        float64
# some_college         float64
# soc_association      float64
# perc_high_cost       float64
# perc_overcrowding    float64
# perc_plumb           float64
# lng_commute          float64
# life_exp             float64
# pre_mortality        float64
# phys_distress        float64
# ment_distress        float64
# diab_prevalence      float64
# food_insecure        float64
# food_access          float64
# perc_rural           float64
# dtype: object

# %% [markdown]
# Let's convert 'Med_inc'(median household income) to a numeric data type as it is currently object/string data type. Let's also convert 'water_violation' to a categorical data type: this is a binary variable which takes on a value of either 0 or 1 to indicate if a water violation has been reported in the county.

# %%
## remove commas from Med_inc column
df['Med_inc']=df['Med_inc'].str.replace(",","")
##change 'Med_inc' to dtype integer
df['Med_inc']=df['Med_inc'].astype('int')

# %%
## change 'water_violation' to dtype category
df['water_violation']=df['water_violation'].astype('category')

# %% [markdown]
# Now, we'll look at missingness in our data. This will determine if observations need to be removed; if imputation needs to be considered; or if observations need to be subsetted.

# %%
## examine missingness 
miss.matrix(df)

# %% [markdown]
# Looking at the plot above, a couple of the feature variables stand out as having missing values: 'GDP' and 'crime_violent' seem to having the most missing observations, closely followed by 'residential_seg','food_index','pop_to_phys','water_violation', 'air_pollution', and 'food_access'. Next, a numeric description of missingness will be generated to see the extent of missingness and determine how best to deal with missing values.

# %%
##numeric visualization of missingness 
df.isnull().sum()
# Out:
# fips                  0
# state                 0
# county                0
# cases                 0
# white_cases           0
# black_cases           0
# hispanic_cases        0
# native_cases          0
# asian_cases           0
# TOT_POP               0
# WH                    0
# BA                    0
# AA                    0
# IA                    0
# HI                    0
# GDP                  19
# pov_perc              0
# Med_inc               0
# Unemployment Rate     0
# traffic_vol           0
# house_burden          0
# ownership             0
# residential_seg       2
# food_index            4
# pop_to_phys           9
# water_violation       1
# air_pollution         4
# uninsured             0
# exercise_opp          0
# income_ineq           0
# crime_violent        56
# high_sch_grad         1
# some_college          0
# soc_association       0
# perc_high_cost        0
# perc_overcrowding     0
# perc_plumb            0
# lng_commute           0
# life_exp              0
# pre_mortality         0
# phys_distress         0
# ment_distress         0
# diab_prevalence       0
# food_insecure         0
# food_access           4
# perc_rural            0
# dtype: int64

# %% [markdown]
# The variable 'crime_violent' has the largest number of missing values. Instead of removing observations with missing values, pandas built-in functionality will be used to fill-in missing values based on information (mean) from the variable/column the missing values belong to. We will start by creating a modified dataframe because imputation using mean does not work on non-numeric data types.

# %%
##create modified dataframe;keep fips in both dataframe to merge after imputation
df2_obj=df[['fips','state', 'county', 'water_violation']]
df2_int=df.drop(columns=['state', 'county', 'water_violation'])
## check shape
print (df2_obj.shape)
print (df2_int.shape)
# Out:
# (974, 4)
# (974, 43)

# %%
## impute using mean for each column
df2_int=df2_int.apply(lambda x: x.fillna(x.mean()),axis=0)

# %%
## check missingness to confirm imputation worked
miss.matrix(df2_int)

# %%
## merge the separated dataframes into one
df2 = pd.merge(left=df2_obj, right=df2_int, how='left',on=["fips"], indicator=True)

# %%
##view left-only merges; 
df2.loc[df2._merge=="left_only",:]
# Out:
# Empty DataFrame
# Columns: [fips, state, county, water_violation, cases, white_cases, black_cases, hispanic_cases, native_cases, asian_cases, TOT_POP, WH, BA, AA, IA, HI, GDP, pov_perc, Med_inc, Unemployment Rate, traffic_vol, house_burden, ownership, residential_seg, food_index, pop_to_phys, air_pollution, uninsured, exercise_opp, income_ineq, crime_violent, high_sch_grad, some_college, soc_association, perc_high_cost, perc_overcrowding, perc_plumb, lng_commute, life_exp, pre_mortality, phys_distress, ment_distress, diab_prevalence, food_insecure, food_access, perc_rural, _merge]
# Index: []
#
# [0 rows x 47 columns]

# %% [markdown]
# Merge is successful!

# %%
##drop _merge column
df2=df2.drop(columns= "_merge")

# %%
## check missingness of entire dataframe
miss.matrix(df2)

# %% [markdown]
# There is one observation missing a value for water violation.Given that it is only one observation, it will be dropped.

# %%
## drop the only observation with an NA
df2=df2.dropna()

# %%
##check shape
df2.shape
# Out:
# (973, 46)

# %% [markdown]
# Before we begin exploring this data, we need to split it into a training and test dataset. Since the outcome variable has not been generated just yet, we will start by creating the outcome variable, then the data will be split into training and test.

# %% [markdown]
# ### Step 1: Create Outcome Variable
# The goal of this project is to examine the factors that lead to racial and ethnic health disparities among racial and ethnic minority population in COVID-19 cases. The outcome variable will be generated by:
# 1. Calculating the COVID-19 percentage share by race and ethnicity for each county
# 2. Calculating the racial/ethnic distribution of populations for each county
# 3. Subtracting the COVID-19 case percentage from the population percentage for each race/ethnicity in each county. If the value is positive, it is indicative of a disparity in COVID-19 cases for that race/ethnicity; if the value is equal to 0, the COVID-19 cases for that race/ethnicity is the same as their population; lastly, if the value is negative, the COVID-19 cases for that race/ethnicity is less than their share of the population. This disparity metric calculation was taken from the CDC: https://www.cdc.gov/nchs/nvss/vsrr/covid19/health_disparities.htm.
#
# **NOTE: Unlike the first attempt, there will be five outcome variables which will measure disparity with in a county for each race/ethnicity for which a disparity has been found (Black, Hispanic, Native American. See also https://www.npr.org/sections/health-shots/2020/05/30/865413079/what-do-coronavirus-racial-disparities-look-like-state-by-state). This decision is motivated by the results from the previous model as well as literature on disparity research which notes that the influence of/experience with the county characteristics used in these models will vary for different racial/ethnic groups.**

# %% [markdown]
# #### 1. Calculating the COVID-19 percentage share by race and ethnicity for each county

# %% [markdown]
# ##### Black Cases

# %%
##calculate percentage share of black cases out of  total cases
df2['cases_bl_pop']=df2['black_cases']/df2['cases']

# %% [markdown]
# ##### Native American Cases

# %%
df2['cases_na_pop']=df2['native_cases']/df2['cases']

# %% [markdown]
# ##### Hispanic Cases

# %%
df2['cases_hi_pop']=df2['hispanic_cases']/df2['cases']

# %% [markdown]
# ##### Asian American Cases

# %%
df2['cases_aa_pop']=df2['asian_cases']/df2['cases']

# %% [markdown]
# #### 2. Calculating the racial/ethnic distribution of populations for each county

# %% [markdown]
# ##### Black Cases

# %%
##calculate percentage of black population out of total population 
df2['bl_pop']=df2['BA']/df2['TOT_POP']

# %% [markdown]
# ##### Native American Cases

# %%
##calculate percentage of natite american population out of total population 
df2['na_pop']=df2['IA']/df2['TOT_POP']

# %% [markdown]
# ##### Hispanic Cases

# %%
##calculate percentage of hispanic population out of total population 
df2['hi_pop']=df2['HI']/df2['TOT_POP']

# %% [markdown]
# ##### Asian American Cases

# %%
##calculate percentage of asian american population out of total population 
df2['aa_pop']=df2['AA']/df2['TOT_POP']

# %% [markdown]
# #### 3. Subtracting the COVID-19 case percentage from the population percentage for each race/ethnicity in each county.

# %% [markdown]
# ##### Black Cases

# %%
##create disparity index
df2['disp_index_BA']=df2['cases_bl_pop']-df2['bl_pop']
##multiply by 100
df2['disp_index_BA'] = df2['disp_index_BA'].apply(lambda x: x*10)

# %% [markdown]
# ##### Native American Cases

# %%
##create disparity index
df2['disp_index_NA']=df2['cases_na_pop']-df2['na_pop']
##multiply by 100
df2['disp_index_NA'] = df2['disp_index_NA'].apply(lambda x: x*10)

# %% [markdown]
# ##### Hispanic Cases

# %%
##create disparity index
df2['disp_index_HI']=df2['cases_hi_pop']-df2['hi_pop']
##multiply by 100
df2['disp_index_HI'] = df2['disp_index_HI'].apply(lambda x: x*10)

# %% [markdown]
# ##### Asian American Cases

# %%
##create disparity index
df2['disp_index_AA']=df2['cases_aa_pop']-df2['aa_pop']
##multiply by 100
df2['disp_index_AA'] = df2['disp_index_AA'].apply(lambda x: x*10)

# %% [markdown]
# ### Step 1.2: Examine correlations and select variables

# %%
## pearson correlation matrix
corr=df2.corr(method ='pearson')

# %%
## isolate variable sets with a correlation greater than 0.7 or less than -0.7
corr_high=corr[((corr >= .7) | (corr <= -.7)) & (corr !=1.000000)]

# %%
## import seaborn to graph correlation
import seaborn as sn

# %%
## plot correlation matrix 
plt.figure(figsize=(50,10))
sn.heatmap(corr_high, annot=True, linewidths=1, linecolor='grey',xticklabels=True, yticklabels=1)
plt.show()

# %% [markdown]
# Insights from matrix:
# 1. Since the COVID-19 cases variables are correlated with one another and because they were used to create the outcome variables, these variables will be removed from all modeling approaches.
# 2. Total population is highly correlated with GDP. It will be dropped from all four modeling pipelines.
# 3. White population is highly corelated with GDP.This variable will be removed when running four separate modeling piplines for the four outcome variables.
# 4. Asian american population is highly correlated with GDP. This variable will be removed when running four separate modeling piplines for the four outcome variables.
# 5. Hispanic population will be removed only when using the disparity index which tracks disparity for hispanic population in county as an outcome variable. It is only highly correlated with the COVID-19 case variables which will be removed from all four modeling pipelines.
# 6. Native American population will be removed only when using the disparity index which tracks disparity for native american population in county as an outcome variable. It is not highly correlated with any of the other features.
# 7. Black population will be removed only when using the disparity index which tracks disparity for black population in county as an outcome variable. It is highly correlated with the COVID-19 cases variables which will be removed from all four modeling pipelines.
# 5. Poverty rate is highly correlated with food insecruity , mental distress , physical distress , premature mortality, food index, and  median income.
# 6. Median income is correlated with food insecure, mental distress, phsical distress, premature mortality, life expectany, and poverty rate.
#
#   - To remedy this (i.e., correlations identified in #5 and #6), median income will be dropped and poverty rate will be retained.
#
#
# 7. Housing burden highly correlated with percentage of population with high housing costs (perc_high_cost). Housing burden will be removed.
# 8. Food index highly correlated with poverty rate, premature mortality, physical distress, mental distress, food insecurity and food access. Food access will be retained in place of food index and food insecure. This is because food insecure and food index are highly correlated with other important variables (ex: life expectancy) as well.
#
# 9. Exercise opportunity highly correlated with percent rural. Percent rural will be dropped.
#
# 10. Life expectancy highly correlated with median income , premature mortality, physical distress, mental distress, and food insecure.
# 11. Premature mortality highly correlated with food index, pov percent; median income; life exp, physical distress, mental distress, and food insecure.
# 12. Physical distress is highly correlated with poverty, median income, food index,life expectancy, premature mortality, mental distress, and food insecure
# 13. Mental distress is highly corr with poverty, median income, food index, life expectancy, premature mortality, physical  distress, and food insecure.
#
#   - To remedy this (i.e., correlations identified in #10 to #13), premature mortality; physical distress, and mental distress will be removed from all four modeling attempts.

# %%
## remove variables identified above. 
df2=df2.drop(columns=['cases','black_cases','white_cases','native_cases','hispanic_cases', 'asian_cases',
                     'TOT_POP','WH', 'AA', 'Med_inc','house_burden','food_index', 'food_insecure', 'perc_rural',
                     'pre_mortality','phys_distress','ment_distress'])

# %% [markdown]
# ### Step 2: Separate into training and test data sets

# %% [markdown]
# For now, we will isolate the four outcomes from the features and explore the features to identify high-level processing steps. Next, the high-level processing will be applied to the entire dataframe (df2) and the features and outcomes will be isolated again. Then, prior to the modeling process, a training and test split will be done. Note that the training and test split and the modeling process will be done four times for the four outcome variabels.

# %%
## isolate outcomes from features; disparity index for black population will be used as the main outcome for now
y = df2[['disp_index_BA']]
X = df2.drop(columns=['disp_index_BA','disp_index_NA','disp_index_HI','disp_index_AA'])

# %%
## split in to training (75% of data) and test (25% of data); set random state to replicate same split every time
train_X, test_X, train_y, test_y = train_test_split(X,y,test_size = .25,random_state=123)

# %%
##check shape to confirm split
print(train_X.shape[0]/df2.shape[0])
print(test_X.shape[0]/df2.shape[0])
# Out:
# 0.7492291880781089
# 0.25077081192189105

# %% [markdown]
# ### Step 3: Explore training dataset

# %%
##view first 20 observations
train_X.head(20)
# Out:
#       fips state             county water_violation     BA     IA      HI  \
# 804  42063    PA     Indiana County             1.0   2364    149    1146
# 280  17153    IL     Pulaski County             0.0   1635     39     134
# 971  56021    WY     Laramie County             1.0   2510   1141   14843
# 453  26157    MI     Tuscola County             0.0    695    359    1873
# 525  28061    MS      Jasper County             0.0   8712     51     237
# 457  27003    MN       Anoka County             1.0  26336   3179   17370
# 429  26073    MI    Isabella County             0.0   1864   2877    2889
# 269  17109    IL   McDonough County             0.0   1630    119     874
# 298  19017    IA      Bremer County             0.0    302     40     405
# 249  17019    IL   Champaign County             1.0  29029    766   13117
# 743  39093    OH      Lorain County             0.0  27797   1194   32185
# 275  17133    IL      Monroe County             0.0    153     87     570
# 558  28137    MS        Tate County             0.0   8750     84     781
# 388  21239    KY    Woodford County             0.0   1338     73    1835
# 346  20059    KS    Franklin County             0.0    385    235    1083
# 107   8031    CO      Denver County             0.0  70981  12682  212984
# 650  37009    NC        Ashe County             0.0    262    114    1390
# 777  41039    OR        Lane County             1.0   4826   6265   35623
# 841  45045    SC  Greenville County             0.0  96583   2584   49792
# 942  55023    WI    Crawford County             0.0    361     60     285
#
#             GDP  pov_perc  Unemployment Rate  ...  diab_prevalence  \
# 804   4244361.0      15.5                5.0  ...            0.107
# 280    263742.0      19.7                6.6  ...            0.196
# 971   5742537.0       9.1                3.5  ...            0.094
# 453   1423947.0      12.7                5.1  ...            0.076
# 525    534860.0      19.0                6.8  ...            0.223
# 457  15380653.0       5.6                3.1  ...            0.089
# 429   2583490.0      23.4                3.8  ...            0.080
# 269   1298699.0      21.9                4.7  ...            0.094
# 298   1151692.0       6.6                2.3  ...            0.082
# 249  11675933.0      19.2                3.8  ...            0.093
# 743  11251295.0      14.2                4.3  ...            0.133
# 275   1031460.0       4.3                3.1  ...            0.089
# 558    525767.0      17.6                5.6  ...            0.140
# 388   1049008.0       9.4                3.1  ...            0.090
# 346    899329.0       9.3                3.3  ...            0.095
# 107  77455208.0      11.7                2.7  ...            0.051
# 650    796238.0      16.9                3.7  ...            0.173
# 777  17205000.0      18.1                4.1  ...            0.087
# 841  30906085.0      11.1                2.4  ...            0.109
# 942    787074.0      12.9                4.3  ...            0.152
#
#      food_access  cases_bl_pop  cases_na_pop  cases_hi_pop  cases_aa_pop  \
# 804     0.090719      0.000000      0.000000      0.000000      0.000000
# 280     0.095931      0.000000      0.000000      0.208333      0.000000
# 971     0.104891      0.000000      0.000000      0.000000      0.000000
# 453     0.013405      0.029940      0.000000      0.000000      0.000000
# 525     0.061348      0.663934      0.000000      0.000000      0.000000
# 457     0.064891      0.220679      0.000000      0.054012      0.034722
# 429     0.036904      0.000000      0.000000      0.000000      0.000000
# 269     0.067317      0.176471      0.000000      0.000000      0.000000
# 298     0.017076      0.000000      0.000000      0.000000      0.000000
# 249     0.044982      0.165010      0.000000      0.435388      0.000000
# 743     0.078758      0.077348      0.000000      0.000000      0.000000
# 275     0.051660      0.000000      0.000000      0.000000      0.000000
# 558     0.151932      0.339623      0.000000      0.000000      0.000000
# 388     0.115641      0.000000      0.000000      0.000000      0.000000
# 346     0.176593      0.000000      0.000000      0.000000      0.000000
# 107     0.045293      0.079208      0.003883      0.394681      0.017666
# 650     0.022912      0.000000      0.000000      0.333333      0.000000
# 777     0.063437      0.000000      0.000000      0.000000      0.000000
# 841     0.128894      0.216889      0.000000      0.153778      0.000000
# 942     0.046492      0.000000      0.000000      0.000000      0.000000
#
#        bl_pop    na_pop    hi_pop    aa_pop
# 804  0.028118  0.001772  0.013631  0.010919
# 280  0.306467  0.007310  0.025117  0.004311
# 971  0.025226  0.011467  0.149176  0.013588
# 453  0.013303  0.006871  0.035850  0.003484
# 525  0.531771  0.003113  0.014466  0.001404
# 457  0.073787  0.008907  0.048666  0.049756
# 429  0.026677  0.041175  0.041347  0.018276
# 269  0.054915  0.004009  0.029445  0.024762
# 298  0.012050  0.001596  0.016160  0.011531
# 249  0.138438  0.003653  0.062555  0.109143
# 743  0.089716  0.003854  0.103879  0.013575
# 275  0.004417  0.002512  0.016456  0.006034
# 558  0.308958  0.002966  0.027577  0.003460
# 388  0.050049  0.002731  0.068639  0.007406
# 346  0.015072  0.009200  0.042397  0.005520
# 107  0.097607  0.017439  0.292878  0.040819
# 650  0.009631  0.004191  0.051097  0.005073
# 777  0.012631  0.016398  0.093238  0.031672
# 841  0.184480  0.004936  0.095106  0.026964
# 942  0.022379  0.003720  0.017668  0.006447
#
# [20 rows x 37 columns]

# %% [markdown]
# __What is the distribution of the feature variables?__

# %% [markdown]
# Check the distribution of all continious variables coded with dtype 'int'.

# %%
## view continous int variables
d = train_X.select_dtypes(include="int").melt()
(
    ggplot(d,aes(x="value")) +
    geom_histogram(bins=25) +
    facet_wrap("variable",scales='free') +
    theme(figure_size=(10,5),
          subplots_adjust={'wspace':0.25})
)
# Out:
# <ggplot: (8782848928519)>

# %% [markdown]
# The 'fips' variable will not be included in the model. The rest of the variables have a right skew. These variables represent a county's population by race/ethnicity. Let's log these variables and see how their distribution changes

# %%
## check if any of the variables have a value of 0 before taking their log
print((train_X == 0).sum())
# Out:
# fips                   0
# state                  0
# county                 0
# water_violation      437
# BA                     0
# IA                     0
# HI                     0
# GDP                    0
# pov_perc               0
# Unemployment Rate      0
# traffic_vol            0
# ownership              0
# residential_seg        0
# pop_to_phys            0
# air_pollution          0
# uninsured              0
# exercise_opp           1
# income_ineq            0
# crime_violent          0
# high_sch_grad          0
# some_college           0
# soc_association        1
# perc_high_cost         0
# perc_overcrowding      0
# perc_plumb             0
# lng_commute            0
# life_exp               0
# diab_prevalence        0
# food_access            1
# cases_bl_pop         360
# cases_na_pop         690
# cases_hi_pop         454
# cases_aa_pop         618
# bl_pop                 0
# na_pop                 0
# hi_pop                 0
# aa_pop                 0
# dtype: int64

# %% [markdown]
# Variables to add 1 to when logging: exercise_opp, soc_association, and  food_access. Note that water violation is a categorical variable. It will be changed to a category dtypes in the high-level preprocessing stage. The other variables with zeros will not be included in the modeling process because they were generated to create the outcome variables.

# %%
## check min value to confirm absence of negative values before taking the log of any of the variables
print(train_X.min())
# Out:
# fips                        1001
# state                         AK
# county                Ada County
# water_violation                0
# BA                             9
# IA                             9
# HI                            63
# GDP                       111976
# pov_perc                     2.6
# Unemployment Rate            1.6
# traffic_vol              2.06772
# ownership               0.196073
# residential_seg          6.22173
# pop_to_phys              440.142
# air_pollution                3.9
# uninsured               0.026826
# exercise_opp                   0
# income_ineq              3.07678
# crime_violent            10.0083
# high_sch_grad           0.525641
# some_college            0.285632
# soc_association                0
# perc_high_cost         0.0491582
# perc_overcrowding     0.00255319
# perc_plumb           0.000407747
# lng_commute                0.074
# life_exp                 70.4621
# diab_prevalence            0.019
# food_access                    0
# cases_bl_pop                   0
# cases_na_pop                   0
# cases_hi_pop                   0
# cases_aa_pop                   0
# bl_pop                0.00339359
# na_pop                0.00100932
# hi_pop                0.00809454
# aa_pop                0.00115875
# dtype: object

# %%
##log variables
d = train_X.copy()
d['ln_BA'] =  np.log(d['BA'])
d['ln_IA'] =  np.log(d['IA'] )
d['ln_HI'] =  np.log(d['HI'])

# %%
##keep only logged variables
d=d.loc[:, d.columns.str.startswith('ln_')]
##transform from wide to long for visualization
d=d.melt()

# %%
##visualize
(
    ggplot(d,aes(x="value")) +
    geom_histogram(bins=25) +
    facet_wrap("variable",scales='free') +
    theme(figure_size=(10,5),
          subplots_adjust={'wspace':0.25})
)
# Out:
# <ggplot: (8782822134694)>

# %% [markdown]
# Logging seems to have normalized the distribution of the population variables. This will be applied to the entire dataframe in the high-level pre-processing stage.
#
# Next, let us visualize the continious variables with dtype=float.

# %%
## view continious float variables
e = train_X.select_dtypes(include="float").melt()
(
    ggplot(e,aes(x="value")) +
    geom_histogram(bins=25) +
    facet_wrap("variable",scales='free') +
    theme(figure_size=(10,5),
          subplots_adjust={'wspace':0.25})
)
# Out:
# <ggplot: (8782850145883)>

# %% [markdown]
# The variables that start with 'cases_' and the variables that end with '_ pop' will not be included in the modeling process because they were created to generate the outcome variables. GDP, Unemployment Rate, ownership, pop_to_phys, crime_violent, perc_plumb, perc_overcrowding, and traffic volume seem to have a pronounced skew. Let us log these variables and see how they look:

# %%
##log variables
d = train_X.copy()
d['ln_GDP'] =  np.log(d['GDP'] )
d['ln_Unemployment Rate'] =  np.log(d['Unemployment Rate'] )
d['ln_ownership'] =  np.log(d['ownership'] )
d['ln_pop_to_phys'] =  np.log(d['pop_to_phys'] )
d['ln_traffic_vol'] =  np.log(d['traffic_vol'] )
d['ln_perc_plumb'] =  np.log(d['perc_plumb'] )
d['ln_perc_overcrowding'] =  np.log(d['perc_overcrowding'] )
d['ln_crime_violent'] =  np.log(d['crime_violent'] )

# %%
##keep only logged variables
d=d.loc[:, d.columns.str.startswith('ln_')]
##transform from wide to long for visualization
d=d.melt()

# %%
##visualize
(
    ggplot(d,aes(x="value")) +
    geom_histogram(bins=25) +
    facet_wrap("variable",scales='free') +
    theme(figure_size=(10,5),
          subplots_adjust={'wspace':0.25})
)
# Out:
# <ggplot: (8782821184241)>

# %% [markdown]
# Logging seems to have normalized most of the variables, however, the variables 'ownership' has not benefitted from logging. It will be turned into categorical varaibles in the high-level preprocessing stage.

# %% [markdown]
# Now let us look at the distribution of the only categorical variable. Based on the data source, "1 means “Yes” and indicates that at least one community water system in the county received at least one health-based violation during the specified time frame. 0 means “No” and indicates that there were no health-based drinking water violations in any community drinking water system in the county."https://www.countyhealthrankings.org/explore-health-rankings/measures-data-sources/county-health-rankings-model/health-factors/physical-environment/air-water-quality/drinking-water-violations

# %%
##categorical variables
f = train_X.select_dtypes(include="category").melt()
(
    ggplot(f,aes(x="value")) +
    geom_bar() +
    facet_wrap("variable",scales='free') +
    theme(figure_size=(10,5),
          subplots_adjust={'wspace':0.25,
                           'hspace':0.75},
         axis_text_x=element_text(rotation=45, hjust=1))
)
# Out:
# <ggplot: (8782821377374)>

# %% [markdown]
# Majority of the counties in the training data set have not recieved a health-based drinking water violation in 2018. Conversely, over 200 counties have recieved a  health-based drinking water violation in 2018.

# %% [markdown]
# __What is the distribution of the outcome variable?__

# %% [markdown]
# Let's look at how each disparity index is distributed for the black population. We will look at the other outcome variables right before we begin modeling for each of them.

# %%
##distribution of outcome variable (disp_index_BA) 
(
    ggplot(train_y,
           aes(x="disp_index_BA")) +
    geom_histogram() +
    theme_minimal() +
    theme(figure_size = (7,3)) 
)
# Out:
# <ggplot: (8782822057358)>

# %% [markdown]
# Similar to attempt 1, it appears that, for majority of the counties represented in the training data set, the disparity index has a value less than zero. There are fewer observations the are greater than 0 on the disparity index (i.e, where disparity is detected). However, those few observations indicate quite a high disparity (see x-axis at around 10).

# %% [markdown]
# ### Step 4:  High-level preprocessing

# %% [markdown]
# Similar to attempt 3,  I will log and bin variables based on the insights from the exploration of the training data above.

# %% [markdown]
# #### `BA`: Black  Population

# %%
df2['BA'] =  np.log(df2['BA'])

# %% [markdown]
# #### `IA`: Native American Population

# %%
df2['IA'] =  np.log(df2['IA'])

# %% [markdown]
# #### `HI`: Hispanic  Population

# %%
df2['HI'] =  np.log(df2['HI'])

# %% [markdown]
# #### `GDP`: County-Level GDP

# %%
df2['GDP'] =  np.log(df2['GDP'] )

# %% [markdown]
# #### `Unemployment Rate`: County-Level Unemployment Rate

# %%
df2['Unemployment Rate'] =  np.log(df2['Unemployment Rate'])

# %% [markdown]
# #### `ownership`: County-Level Homeownership

# %%
median_ownership = df2.loc[df2['ownership'] > 0,'ownership'].median()
df2['ownership'] =  np.where(df2['ownership']==0,0,np.where(df2['ownership'] <= median_ownership,1,2))

# %% [markdown]
# #### `pop_to_phys`: County-Level Ration of Physician to Population

# %%
df2['pop_to_phys'] =  np.log(df2['pop_to_phys'])

# %% [markdown]
# #### `perc_overcrowding`: Percentage of households with overcrowding

# %%
df2['perc_overcrowding'] =  np.log(df2['perc_overcrowding'])

# %% [markdown]
# #### `perc_plumbing`: Percentage of households with lack of kitchen or plumbing facilities

# %%
df2['perc_plumb'] =  np.log(df2['perc_plumb'])

# %% [markdown]
# #### `traffic_vol`: County-Level Traffic Volume

# %%
df2['traffic_vol'] =  np.log(df2['traffic_vol'])

# %% [markdown]
# #### `crime_violent`: County-Level Violent Crime Rate

# %%
df2['crime_violent'] =  np.log(df2['crime_violent'])

# %% [markdown]
# ### Step 5: Resplit data

# %% [markdown]
# **Outcome Variable `disp_index_BA`: Diparity index tracking COVID-19 case disparity in Black Population**

# %% [markdown]
# Now let's resplit the pre-processed data frame and attempt the modeling process of the outcome variable 'disp_index_BA'--index tracking disparity amongst the Black population in a county.

# %%
##isolate outcome and features
y = df2[['disp_index_BA']]
##drop irrelevant columns when isolating features from outcome (including other outcome variables)
X = df2.drop(columns=['disp_index_BA','fips','state','county','cases_bl_pop', 'cases_na_pop',
       'cases_hi_pop', 'cases_aa_pop', 'bl_pop', 'na_pop', 'hi_pop', 'aa_pop',
                     'disp_index_BA','disp_index_NA','disp_index_HI','disp_index_AA'])
## also remove black population column because it was used to create the outcome variable
X=X.drop(columns=['BA'])

# %%
## split in to training (75% of data) and test (25% of data); set random state to replicate same split every time
train_X, test_X, train_y, test_y = train_test_split(X,y,test_size = .25,random_state=123)

# %%
##check shape to confirm split
print(train_X.shape[0]/df2.shape[0])
print(test_X.shape[0]/df2.shape[0])
# Out:
# 0.7492291880781089
# 0.25077081192189105

# %% [markdown]
# ### Step 6:  Pre-Processing

# %% [markdown]
# Let's rescale our training data for now, but we'll put the preprocessing into a modeling pipeline later on.

# %%
## scale so variables are on the same scale
scaler = pp.MinMaxScaler()
col_names = list(train_X)
train_X = scaler.fit_transform(train_X)

# %%
# Convert back into data frame
train_X = pd.DataFrame(train_X,columns=col_names)
train_X
# Out:
#      water_violation        IA        HI       GDP  pov_perc  \
# 0                1.0  0.293751  0.281449  0.415079  0.368571
# 1                0.0  0.153467  0.073222  0.097823  0.488571
# 2                1.0  0.506808  0.529944  0.449599  0.185714
# 3                0.0  0.385786  0.329112  0.290368  0.288571
# 4                0.0  0.181543  0.128546  0.178558  0.468571
# ..               ...       ...       ...       ...       ...
# 724              1.0  0.631561  0.628520  0.523522  0.360000
# 725              0.0  0.072545  0.115415  0.162360  0.257143
# 726              0.0  0.372434  0.355876  0.374810  0.397143
# 727              1.0  0.297205  0.255493  0.414398  0.448571
# 728              1.0  0.083572  0.065698  0.205037  0.962857
#
#      Unemployment Rate  traffic_vol  ownership  residential_seg  pop_to_phys  \
# 0             0.489600     0.535046        0.0         0.473474     0.370712
# 1             0.608894     0.181632        1.0         0.270165     0.437828
# 2             0.336341     0.633521        0.0         0.176668     0.308317
# 3             0.498109     0.259540        1.0         0.290183     0.512600
# 4             0.621722     0.158887        1.0         0.287885     0.664046
# ..                 ...          ...        ...              ...          ...
# 724           0.174223     0.580320        0.0         0.317080     0.271949
# 725           0.284194     0.735788        1.0         0.575570     0.392135
# 726           0.382839     0.616528        0.0         0.201460     0.373170
# 727           0.545901     0.535448        0.0         0.322639     0.238086
# 728           0.816508     0.384788        0.0         0.224375     0.426718
#
#      ...  high_sch_grad  some_college  soc_association  perc_high_cost  \
# 0    ...       0.866136      0.491930         0.461680        0.334553
# 1    ...       0.905910      0.483474         0.675570        0.219965
# 2    ...       0.582123      0.696412         0.372681        0.179971
# 3    ...       0.703772      0.449728         0.358101        0.270971
# 4    ...       0.651017      0.379894         0.293502        0.261529
# ..   ...            ...           ...              ...             ...
# 724  ...       0.740250      0.573974         0.243100        0.273840
# 725  ...       0.978976      0.515004         0.291942        0.162940
# 726  ...       0.911022      0.701145         0.276162        0.377166
# 727  ...       0.872051      0.637511         0.459451        0.257014
# 728  ...       0.742750      0.443238         0.127949        0.311171
#
#      perc_overcrowding  perc_plumb  lng_commute  life_exp  diab_prevalence  \
# 0             0.448270    0.699529     0.370995  0.277770         0.273292
# 1             0.305564    0.625561     0.622260  0.220759         0.549689
# 2             0.384751    0.432532     0.003373  0.323014         0.232919
# 3             0.489922    0.442468     0.576728  0.269320         0.177019
# 4             0.566957    0.657974     0.689713  0.183693         0.633540
# ..                 ...         ...          ...       ...              ...
# 724           0.671138    0.564946     0.325464  0.296157         0.217391
# 725           0.551379    0.446569     0.365936  0.213910         0.332298
# 726           0.297860    0.524994     0.456998  0.223345         0.260870
# 727           0.346351    0.385131     0.295110  0.142446         0.416149
# 728           0.784177    0.525071     0.288364  0.061189         0.329193
#
#      food_access
# 0       0.191425
# 1       0.202423
# 2       0.221329
# 3       0.028286
# 4       0.129449
# ..           ...
# 724     0.127882
# 725     0.178710
# 726     0.228526
# 727     0.199767
# 728     0.234518
#
# [729 rows x 25 columns]

# %% [markdown]
# ### Step 6: Modeling
#
# We have a continuously distributed outcome variable i.e., a regression problem.Let's test how these models perform
#
# - Linear Regression
# - KNN
# - Random Forest

# %%
## set fold generator to split and test on same data across models
fold_generator = KFold(n_splits=5, shuffle=True,random_state=111)

# %% [markdown]
# Let's run each model individually then compare the performance of the different models in a plot.
#
# We'll use **root mean squared error** as our performance metrics.

# %%
## performance metric
use_metrics = ["neg_root_mean_squared_error"]

# %% [markdown]
# #### Linear Model

# %%
lm_scores = cross_validate(LM(),train_X,train_y, cv = fold_generator, scoring =use_metrics)

# %% [markdown]
# #### KNN

# %%
knn_scores = cross_validate(KNN(),train_X,train_y, cv = fold_generator, scoring =use_metrics)

# %% [markdown]
# #### Random Forest

# %%
rf_scores = cross_validate(RF(),train_X,train_y, cv = fold_generator, scoring =use_metrics)

# %% [markdown]
# Let's collect the scores from each model and compare their performance.

# %%
# Collect all the metrics we care about as a dictionary 
collect_scores = \
dict(lm = lm_scores['test_neg_root_mean_squared_error']*-1,
     knn = knn_scores['test_neg_root_mean_squared_error']*-1,
     rf = rf_scores['test_neg_root_mean_squared_error']*-1)

# Convert to a data frame and reshape
collect_scores = pd.DataFrame(collect_scores)
collect_scores
# Out:
#          lm       knn        rf
# 0  1.231453  1.347707  1.278981
# 1  0.953424  0.941801  0.914748
# 2  1.114775  1.083411  1.248826
# 3  1.209417  1.248301  1.183074
# 4  1.305927  1.259187  1.329139

# %%
##rename models
collect_scores=collect_scores.rename(columns={'lm':'Linear Model', 'knn':'KNN','rf':'Random Forest'})

# %%
## let's visualize using seaborn
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})
ax = sns.boxplot(data=collect_scores, orient="h", palette="Blues")

# %% [markdown]
# Let's use ggplot for visualization, too.

# %%
##turn from wide to long for visualization
collect_scores=collect_scores.melt(var_name="Model",value_name="Root MSE")

# %%
# Get the order of the models
order = (collect_scores.groupby('Model').mean().sort_values(by="Root MSE").index.tolist())

# Plot
MSE_model_4=(
    ggplot(collect_scores,
          aes(x="Model",y="Root MSE")) +
    geom_boxplot(fill="red", alpha=0.5) +
    scale_x_discrete(limits=order) +
    labs(x="Model",y="Root Mean Squared Error") +
    ##scale_color_brewer(palette="Blues") +
    coord_flip() + theme_classic()+ ggtitle("Distribution of Root Mean Squared Error by Model")
    + theme(dpi=100,
        legend_position="bottom",
        legend_direction="horizontal",
        legend_title_align="center",
        legend_box_spacing=0.4,
        legend_key=element_blank(),
        axis_line=element_line(size=1, colour="black"),
        panel_grid_major=element_line(colour="#d3d3d3"),
        panel_grid_minor=element_blank(),
        panel_border=element_blank(),
        panel_background=element_blank(),
        plot_title=element_text(size=15, family="Tahoma", 
                                face="bold"),
        text=element_text(family="Tahoma", size=11),
        axis_text_x=element_text(colour="black", size=10),
        axis_text_y=element_text(colour="black", size=10),
    )

)
MSE_model_4
##MSE_model_3.save("MSE_model_3.png")
# Out:
# <ggplot: (8782822442490)>

# %% [markdown]
# Given that root mean squared error is easier to interpret (incorporating feedback from presentation)the mean squared errors fall in the range of a little less than 1 to over 1.3. The Linear Model and KNN beat out the Random Forest here, but note that the average as represented by the black line in each box is smaller in the Random Forest than in the Linear model or KNN.

# %% [markdown]
# ### Tuning: KNN, Decision Tree, and Random Forest

# %% [markdown]
# #### KNN

# %%
## try different number of neighbours to see which does best
knn_tune_params = {'n_neighbors':[1, 10, 25, 35, 50, 75, 100, 250]}

# %%
## wrap tuning parameter in GridSearchCV
tune_knn = GridSearchCV(KNN(),knn_tune_params,
                        cv = fold_generator,
                        scoring='neg_root_mean_squared_error',
                        n_jobs=4)

# %%
## fit model
tune_knn.fit(train_X,train_y)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=111, shuffle=True),
#              estimator=KNeighborsRegressor(), n_jobs=4,
#              param_grid={'n_neighbors': [1, 10, 25, 35, 50, 75, 100, 250]},
#              scoring='neg_root_mean_squared_error')

# %%
## see best parameter: how many neighbours?
tune_knn.best_params_
# Out:
# {'n_neighbors': 10}

# %%
## what is the best score?
tune_knn.best_score_
# Out:
# -1.1718930896026905

# %% [markdown]
# #### Random Forest

# %%
## try different number for the 'max_depth','n_estimators', and 'max_features' parameters
rf_params = {'max_depth':[5, 10, 20],
             'n_estimators':[100,500,1000],
              'max_features': [10,20,30]}

# %%
## wrap parameters in GridSearchCV
tune_rf = GridSearchCV(RF(),rf_params,
                        cv = fold_generator,
                        scoring='neg_root_mean_squared_error',
                        n_jobs=4)

# %%
## fit the model
tune_rf.fit(train_X,train_y)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=111, shuffle=True),
#              estimator=RandomForestRegressor(), n_jobs=4,
#              param_grid={'max_depth': [5, 10, 20], 'max_features': [10, 20, 30],
#                          'n_estimators': [100, 500, 1000]},
#              scoring='neg_root_mean_squared_error')

# %%
## best parameters
tune_rf.best_params_
# Out:
# {'max_depth': 20, 'max_features': 10, 'n_estimators': 500}

# %%
## best score
tune_rf.best_score_
# Out:
# -1.1528336100198202

# %% [markdown]
# After trying different configurations for the parameters, the Random Forest performed better than KNN. The insights from tuning (i.e,. how to configure parameters) will be incorporated in the modeling pipeline below.

# %% [markdown]
# ### Modeling Pipeline

# %%
# (0) Split the data 
train_X, test_X, train_y, test_y = train_test_split(X,y,test_size=.25,random_state=123)

# (1) Set the folds index to ensure comparable samples
fold_generator = KFold(n_splits=5, shuffle=True,random_state=111)

# (2) Next specify the preprocessing steps
preprocess = ColumnTransformer(transformers=[('num', pp.MinMaxScaler(), ['water_violation', 'IA', 'HI', 'GDP', 'pov_perc', 'Unemployment Rate',
       'traffic_vol', 'ownership', 'residential_seg', 'pop_to_phys',
       'air_pollution', 'uninsured', 'exercise_opp', 'income_ineq',
       'crime_violent', 'high_sch_grad', 'some_college', 'soc_association',
       'perc_high_cost', 'perc_overcrowding', 'perc_plumb', 'lng_commute',
       'life_exp', 'diab_prevalence', 'food_access'])])


# (3) Next Let's create our model pipe (note for the model we leave none as a placeholder)
pipe = Pipeline(steps=[('pre_process', preprocess),
                       ('model',None)])


# (4) Specify the models and their repsective tuning parameters. 
# Note the naming convention here to reference the model key
search_space = [
    # Linear Model
    {'model' : [LM()]},
    
    # KNN with K tuning param
    {'model' : [KNN()],
     'model__n_neighbors':[1, 10, 25, 35, 50, 75, 100, 250]},
    
    
    # Random forest with the N Estimators, max depth and max features tuning param
    {'model' : [RF()],
     'model__max_depth':[5, 10, 20],
     'model__n_estimators':[100,500,1000],
     'model__max_features': [10,20,30]},
]


# (5) Put it all together in the grid search
search = GridSearchCV(pipe, search_space, 
                      cv = fold_generator,
                      scoring='neg_root_mean_squared_error',
                      n_jobs=4)

# (6) Fit the model to the training data
search.fit(train_X,train_y)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=111, shuffle=True),
#              estimator=Pipeline(steps=[('pre_process',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          MinMaxScaler(),
#                                                                          ['water_violation',
#                                                                           'IA',
#                                                                           'HI',
#                                                                           'GDP',
#                                                                           'pov_perc',
#                                                                           'Unemployment '
#                                                                           'Rate',
#                                                                           'traffic_vol',
#                                                                           'ownership',
#                                                                           'residential_seg',
#                                                                           'pop_to_phys',
#                                                                           'air_pollution',
#                                                                           'uninsured',
#                                                                           'exercise_opp',
#                                                                           'income_ineq',
#                                                                           'crime_vi...
#                                        ('model', None)]),
#              n_jobs=4,
#              param_grid=[{'model': [LinearRegression()]},
#                          {'model': [KNeighborsRegressor()],
#                           'model__n_neighbors': [1, 10, 25, 35, 50, 75, 100,
#                                                  250]},
#                          {'model': [RandomForestRegressor(max_depth=20,
#                                                           max_features=10)],
#                           'model__max_depth': [5, 10, 20],
#                           'model__max_features': [10, 20, 30],
#                           'model__n_estimators': [100, 500, 1000]}],
#              scoring='neg_root_mean_squared_error')

# %%
## what is the best score
search.best_score_
# Out:
# -1.1533029392056273

# %%
## best parameter configuration
search.best_params_
# Out:
# {'model': RandomForestRegressor(max_depth=20, max_features=10),
#  'model__max_depth': 20,
#  'model__max_features': 10,
#  'model__n_estimators': 100}

# %%
## which model performed best
search.best_estimator_
# Out:
# Pipeline(steps=[('pre_process',
#                  ColumnTransformer(transformers=[('num', MinMaxScaler(),
#                                                   ['water_violation', 'IA',
#                                                    'HI', 'GDP', 'pov_perc',
#                                                    'Unemployment Rate',
#                                                    'traffic_vol', 'ownership',
#                                                    'residential_seg',
#                                                    'pop_to_phys',
#                                                    'air_pollution', 'uninsured',
#                                                    'exercise_opp',
#                                                    'income_ineq',
#                                                    'crime_violent',
#                                                    'high_sch_grad',
#                                                    'some_college',
#                                                    'soc_association',
#                                                    'perc_high_cost',
#                                                    'perc_overcrowding',
#                                                    'perc_plumb', 'lng_commute',
#                                                    'life_exp',
#                                                    'diab_prevalence',
#                                                    'food_access'])])),
#                 ('model',
#                  RandomForestRegressor(max_depth=20, max_features=10))])

# %% [markdown]
# Random Forest regressor is better than the Linear Model and KNN. Let's save this model's best parameter configuration into an object for us in further exploration of the variables.

# %%
## save model and parameter configurations into an object for further exploration below
rf_mod = search.best_estimator_

# %% [markdown]
# Although this is the final attempt for this outcome variables, let's look at how the model used the variables to make its prediction. Afterwards, we see what the test performance is and then continue on to the next outcome variables.

# %%
from sklearn.inspection import permutation_importance

# %%
## let's shuffle the variables 50 times and see which variables the model relied on and which ones it relied the least on
vi = permutation_importance(rf_mod,train_X,train_y,n_repeats=50)

# %%
## organize shuffle results as a data frame 
vi_dat = pd.DataFrame(dict(variable=train_X.columns,
                           vi = vi['importances_mean'],
                           std = vi['importances_std']))

# %%
## generate intervals
vi_dat['low'] = vi_dat['vi'] - 2*vi_dat['std']
vi_dat['high'] = vi_dat['vi'] + 2*vi_dat['std']

# %%
# arrange dataframe in order from most to least important variables 
vi_dat = vi_dat.sort_values(by="vi",ascending=False).reset_index(drop=True)
vi_dat
# Out:
#              variable        vi       std       low      high
# 0           uninsured  0.357995  0.027373  0.303250  0.412741
# 1       air_pollution  0.127707  0.012653  0.102402  0.153013
# 2      perc_high_cost  0.127074  0.010467  0.106139  0.148008
# 3            pov_perc  0.088907  0.003684  0.081540  0.096275
# 4     residential_seg  0.072654  0.004296  0.064061  0.081246
# 5        some_college  0.065779  0.004006  0.057766  0.073792
# 6        exercise_opp  0.051671  0.002890  0.045892  0.057451
# 7         lng_commute  0.051629  0.003245  0.045140  0.058119
# 8                  IA  0.049647  0.002469  0.044709  0.054586
# 9                  HI  0.045305  0.002669  0.039967  0.050642
# 10      crime_violent  0.042696  0.002320  0.038055  0.047336
# 11           life_exp  0.041979  0.002710  0.036558  0.047400
# 12        pop_to_phys  0.041445  0.002210  0.037025  0.045865
# 13      high_sch_grad  0.041303  0.002904  0.035495  0.047111
# 14  Unemployment Rate  0.040588  0.002768  0.035052  0.046124
# 15        traffic_vol  0.040416  0.002932  0.034553  0.046279
# 16  perc_overcrowding  0.036168  0.002150  0.031868  0.040468
# 17        food_access  0.032578  0.002436  0.027706  0.037450
# 18        income_ineq  0.028820  0.002010  0.024800  0.032839
# 19    diab_prevalence  0.028648  0.002037  0.024574  0.032722
# 20                GDP  0.022067  0.001025  0.020017  0.024118
# 21         perc_plumb  0.019113  0.001890  0.015333  0.022894
# 22    soc_association  0.015473  0.000962  0.013548  0.017397
# 23          ownership  0.007455  0.001061  0.005332  0.009578
# 24    water_violation  0.004536  0.000719  0.003097  0.005974

# %%
## visualize the dataframe above using ggplot
(
    ggplot(vi_dat,
          aes(x="variable",y="vi")) +
    geom_col(alpha=.5) +
    geom_point() +
    geom_errorbar(aes(ymin="low",ymax="high"),width=.2) +
    theme_bw() +
    scale_x_discrete(limits=vi_dat.variable.tolist()) +
    coord_flip() +
    labs(y="Reduction in Root MSE",x="")
)
# Out:
# <ggplot: (8782822252108)>

# %% [markdown]
# The five variables the model relied on the most are the number of uninsured people in a county; the percent of people with high housing costs; a measure of air pollution in a county; the level of residential segregation in a county; and the poverty rate in a county.
#
# Let's explore these variables further using partial dependency plots.

# %%
## import requred packages
from sklearn.inspection import partial_dependence
from sklearn.inspection import plot_partial_dependence
from sklearn.inspection import permutation_importance
from pdpbox import pdp

# %%
## modify matplotlib font family to times new roman
from matplotlib import rcParams
rcParams['font.family'] = 'Times New Roman'

# %%
## modify matplot lib font size 
rcParams['axes.labelsize'] = 20
rcParams['axes.titlesize'] = 20

# %%
# Target specific features (top 5 important variables)
features = ['uninsured','perc_high_cost','air_pollution','residential_seg','pov_perc']

# Calculate the partial dependency
fig, ax = plt.subplots(figsize=(15, 7))
ax.set_title("Figure 2: Partial dependence of the oucome variable on the five most important features used by the random forest model")
display = plot_partial_dependence(
    rf_mod, train_X, features,n_cols=5,
    n_jobs=4, grid_resolution=30,ax=ax
)
#fig.savefig('Part1_2.png')

# %% [markdown]
# Like before, almost all the important variables have a negative relationship with the outcome variable. However, there are some irregularities in the relationship. For instance, as the number of uninsured adults increases, we first see a sharp decline in disparity followed by a leveling off. And then, right after the uninsured rate reach a little over 0.1, there is a sharp decline in disparity again.  It looks like, past 0.2 on the x-axis, the disparity seems to level-off.
#
# Similarly, as the percent of poeple with high housing costs increases we see a sharp decline in disparity, where the the Black population in a county far exceeds the number of COVID-19 cases amonst the Black population in a county.
#
# Air pollution has almost a linear downward trend: as air pollution in a county increases, the disparity level decreases. Note that "average air_pollution is a measure of annual concentration of fine particulate pollution in the county. Fine particulate matter is defined as particles of air pollutants with an aerodynamic diameter less than 2.5 micrometers (PM2.5)" (See county health rankings page: https://www.countyhealthrankings.org/explore-health-rankings/measures-data-sources/county-health-rankings-model/health-factors/physical-environment/air-water-quality/air-pollution-particulate-matter).
#
#
# Poverty percent has an intersting distribution. We see that at poverty level of 10 and a little over 10, the disparity remains constant, a sharp increase is observed at around x=20, followed by a sharp decline in disparity.
#
# An intersting insight is that disparity amongst the Black population increases almost linearly with residential segregation.  However, note that the scale of the y-axis is less than zero. Although an increase is observed, according to our index, since these values fall below zero, a disparity is not detected. Nevertheless, it is interesting to see that some observation are closer to disparity than others when residential segregatio goes up.

# %% [markdown]
# Let's use ICE plots to see if there are any interactions/heterogenous effects in the three out of the five most important variables

# %% [markdown]
# Since it is difficult to interpret ICE plots because each observation possess different baselines, the plot will be centered around the baseline (minimum) value of the variable of interest.

# %%
## PDP for feature='uninsured'
pdp_dist = pdp.pdp_isolate(model = rf_mod, 
                           dataset = train_X,
                           model_features = train_X.columns.tolist(),
                           feature="uninsured",num_grid_points=20)

fig,ax = pdp.pdp_plot(pdp_dist,'uninsured',plot_pts_dist=True,
                      center=True,plot_lines=True, # ICE part                          
                      figsize=(15,10))

# %% [markdown]
# Unlike attempt three, it looks like our preprocessing steps have addressed some of the issues of heterogeneity observed, where some lines were going past the baseline and not necessarily following the same direction as the other lines shooting off from the baseline. While there seems to be a general trend of seeing lower measures of disparity as the percent of uninsured adults increases, we still see quite a few variations: for instance looking at the spread of the blue lines, it is evident that for some observations, an increase in the number of uninsured adults is associated with  disparity measures that are closer to zero (i.e, closer to a disparty being detected) while in others, a decrease is met with lower levels of disparity.

# %%
## PDP for feature='perc_high_cost'
pdp_dist = pdp.pdp_isolate(model = rf_mod, 
                           dataset = train_X,
                           model_features = train_X.columns.tolist(),
                           feature="perc_high_cost",num_grid_points=20)

fig,ax = pdp.pdp_plot(pdp_dist,'perc_high_cost',plot_pts_dist=True,
                      center=True,plot_lines=True, # ICE part                          
                      figsize=(15,10))

# %% [markdown]
# There seems to be presence of some heterogenous effects here because ther are clearly quite a few blue lines that shoot above the baseline of zero. There might be something else that is causing this variation.

# %%
## PDP for feature='residential_seg'
pdp_dist = pdp.pdp_isolate(model = rf_mod, 
                           dataset = train_X,
                           model_features = train_X.columns.tolist(),
                           feature="residential_seg",num_grid_points=20)

fig,ax = pdp.pdp_plot(pdp_dist,'residential_seg',plot_pts_dist=True,
                      center=True,plot_lines=True, # ICE part                          
                      figsize=(15,10))

# %% [markdown]
# Looking at the plot above, we see that the observations are generally moving in the same direction. As the measure for residential segregation increases, there is an increase in disparity amongst the Black population in a county. Since there are not  any lines pushing past the baseline, the heterogenous effects are minimal. However, it is evident that some observations have a higher disparity at lower levels of residential segregation.

# %% [markdown]
# ### Test Performance for outcome variable `disp_index_BA`

# %%
## make sure test does not include any NAs
test_X.isnull().sum()
# Out:
# water_violation      0
# IA                   0
# HI                   0
# GDP                  0
# pov_perc             0
# Unemployment Rate    0
# traffic_vol          0
# ownership            0
# residential_seg      0
# pop_to_phys          0
# air_pollution        0
# uninsured            0
# exercise_opp         0
# income_ineq          0
# crime_violent        0
# high_sch_grad        0
# some_college         0
# soc_association      0
# perc_high_cost       0
# perc_overcrowding    0
# perc_plumb           0
# lng_commute          0
# life_exp             0
# diab_prevalence      0
# food_access          0
# dtype: int64

# %%
## check for -inf
test_X.min()
# Out:
# water_violation       0.000000
# IA                    2.995732
# HI                    4.700480
# GDP                  10.900270
# pov_perc              4.900000
# Unemployment Rate     0.530628
# traffic_vol               -inf
# ownership             1.000000
# residential_seg       2.433584
# pop_to_phys           6.545687
# air_pollution         3.400000
# uninsured             0.040723
# exercise_opp          0.000000
# income_ineq           3.480230
# crime_violent         3.587608
# high_sch_grad         0.634000
# some_college          0.208518
# soc_association       0.000000
# perc_high_cost        0.046889
# perc_overcrowding    -6.835185
# perc_plumb                -inf
# lng_commute           0.076000
# life_exp             70.310741
# diab_prevalence       0.038000
# food_access           0.000840
# dtype: float64

# %%
## check for +inf
test_X.max()
# Out:
# water_violation       1.000000
# IA                    9.728956
# HI                   12.764499
# GDP                  18.938024
# pov_perc             42.500000
# Unemployment Rate     2.116256
# traffic_vol           7.652869
# ownership             2.000000
# residential_seg      64.311528
# pop_to_phys           9.896564
# air_pollution        13.300000
# uninsured             0.339399
# exercise_opp          1.000000
# income_ineq           8.473708
# crime_violent         7.312842
# high_sch_grad         0.981818
# some_college          0.903366
# soc_association      38.341721
# perc_high_cost        0.233259
# perc_overcrowding    -2.478629
# perc_plumb           -2.429477
# lng_commute           0.621000
# life_exp             86.061144
# diab_prevalence       0.310000
# food_access           0.317650
# dtype: float64

# %% [markdown]
# There are -inf values in the test data. These will be replaced with 0 because the predict function sklearn cannot deal with inf values.

# %%
## replace -inf values with 0
test_X=test_X.replace([-np.inf, np.nan], 0)

# %%
## confirm removal of -inf 
test_X.min()
# Out:
# water_violation       0.000000
# IA                    2.995732
# HI                    4.700480
# GDP                  10.900270
# pov_perc              4.900000
# Unemployment Rate     0.530628
# traffic_vol           0.000000
# ownership             1.000000
# residential_seg       2.433584
# pop_to_phys           6.545687
# air_pollution         3.400000
# uninsured             0.040723
# exercise_opp          0.000000
# income_ineq           3.480230
# crime_violent         3.587608
# high_sch_grad         0.634000
# some_college          0.208518
# soc_association       0.000000
# perc_high_cost        0.046889
# perc_overcrowding    -6.835185
# perc_plumb           -6.387961
# lng_commute           0.076000
# life_exp             70.310741
# diab_prevalence       0.038000
# food_access           0.000840
# dtype: float64

# %%
# Predict() method will use the best model out of the scan
pred_y = search.predict(test_X)

# %%
## performance using mean squared error
metric1=m.mean_squared_error(test_y,pred_y)

# %%
from math import sqrt

# %%
## determine root mean squared error to compare with training performance
sqrt(metric1)
# Out:
# 1.0313584473678712

# %% [markdown]
# The root mean squared error on the training data is 1.1518916438106654 while on the test data it is 1.0366491340823742. The model seems to have performed better on the test data than the training data. This may have occured because of the cross validation technique used--maybe seeting the k-folds would have resulted in a different arrangement of the training data being used to train the models.

# %%
## performance using r2

# %%
m.r2_score(test_y,pred_y)
# Out:
# 0.1756881433215226

# %% [markdown]
# R-squared value is quite low. The model doesn't seem to explain variations in the outcome variable well. It is not doing a great job of predicting the outcome variable in the test data set. Let's visualize how far off the prediction is from the actual values of the outcome variables.

# %%
## change from array to dataframe for visualization
pred_y=pd.DataFrame(pred_y)

# %%
## reset index 
train_y.reset_index(drop=True, inplace=True)

# %%
## combine pred_y and train_y into one dataframe and visualize
dat = pd.concat([pred_y, train_y], axis=1)

# %%
Part_1=   (
     ggplot(dat,aes(x='pred_y',y="train_y")) +
     geom_point(alpha=.5) +
      geom_abline(color="steelblue",size=1) +
       theme(figure_size=(7,4))+
       labs(title='Figure 1: Predicted outcome values vs. Actual outcome values', x='Predicted outcome values (test data)',
          y='Acutal outcome values (test data)' )+
       theme(dpi=100,
        legend_position="bottom",
        legend_direction="horizontal",
        legend_title_align="center",
        legend_box_spacing=0.4,
        legend_key=element_blank(),
        axis_line=element_line(size=1, colour="black"),
        panel_grid_major=element_line(colour="#d3d3d3"),
        panel_grid_minor=element_blank(),
        panel_border=element_blank(),
        panel_background=element_blank(),
        plot_title=element_text(size=11),
        text=element_text(family="Times New Roman", size=11),
        axis_text_x=element_text(colour="black", size=10),
        axis_text_y=element_text(colour="black", size=10),
  )
   )
Part_1.save("Part_1.png")
Part_1
# Out:
# <ggplot: (8782828344763)>

# %% [markdown]
# ### Re-split and Re-model data for new outcome variable

# %% [markdown]
# **Outcome Variable `disp_index_HI`: Diparity index tracking COVID-19 case disparity in Hispanic Population**

# %% [markdown]
# Now let's resplit the pre-processed data frame and attempt the modeling process of the outcome variable 'disp_index_HI'--index tracking disparity amongst the Hispanic population in a county.

# %%
##isolate outcome and features
y = df2[['disp_index_HI']]
##drop irrelevant columns when isolating features from outcome (including other outcome variables)
X = df2.drop(columns=['fips','state','county','cases_bl_pop', 'cases_na_pop',
       'cases_hi_pop', 'cases_aa_pop', 'bl_pop', 'na_pop', 'hi_pop', 'aa_pop',
                     'disp_index_HI','disp_index_NA','disp_index_BA','disp_index_AA'])
## also remove black population column because it was used to create the outcome variable
X=X.drop(columns=['HI'])

# %% [markdown]
# ### Modeling Pipeline

# %%
# (0) Split the data 
train_X, test_X, train_y, test_y = train_test_split(X,y,test_size=.25,random_state=123)

# (1) Set the folds index to ensure comparable samples
fold_generator = KFold(n_splits=5, shuffle=True,random_state=111)

# (2) Next specify the preprocessing steps
preprocess = ColumnTransformer(transformers=[('num', pp.MinMaxScaler(), ['water_violation', 'IA', 'BA', 'GDP', 'pov_perc', 'Unemployment Rate',
       'traffic_vol', 'ownership', 'residential_seg', 'pop_to_phys',
       'air_pollution', 'uninsured', 'exercise_opp', 'income_ineq',
       'crime_violent', 'high_sch_grad', 'some_college', 'soc_association',
       'perc_high_cost', 'perc_overcrowding', 'perc_plumb', 'lng_commute',
       'life_exp', 'diab_prevalence', 'food_access'])])


# (3) Next Let's create our model pipe (note for the model we leave none as a placeholder)
pipe = Pipeline(steps=[('pre_process', preprocess),
                       ('model',None)])


# (4) Specify the models and their repsective tuning parameters. 
# Note the naming convention here to reference the model key
search_space = [
    # Linear Model
    {'model' : [LM()]},
    
    # KNN with K tuning param
    {'model' : [KNN()],
     'model__n_neighbors':[1, 10, 25, 35, 50, 75, 100, 250]},
    
    # Random forest with the N Estimators tuning param
    {'model' : [RF()],
     'model__max_depth':[5, 10, 20],
     'model__n_estimators':[100,500,1000],
     'model__max_features': [10,20,30]},
]


# (5) Put it all together in the grid search
search = GridSearchCV(pipe, search_space, 
                      cv = fold_generator,
                      scoring='neg_root_mean_squared_error',
                      n_jobs=4)

# (6) Fit the model to the training data
search.fit(train_X,train_y)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=111, shuffle=True),
#              estimator=Pipeline(steps=[('pre_process',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          MinMaxScaler(),
#                                                                          ['water_violation',
#                                                                           'IA',
#                                                                           'BA',
#                                                                           'GDP',
#                                                                           'pov_perc',
#                                                                           'Unemployment '
#                                                                           'Rate',
#                                                                           'traffic_vol',
#                                                                           'ownership',
#                                                                           'residential_seg',
#                                                                           'pop_to_phys',
#                                                                           'air_pollution',
#                                                                           'uninsured',
#                                                                           'exercise_opp',
#                                                                           'income_ineq',
#                                                                           'crime_vi...
#              n_jobs=4,
#              param_grid=[{'model': [LinearRegression()]},
#                          {'model': [KNeighborsRegressor()],
#                           'model__n_neighbors': [1, 10, 25, 35, 50, 75, 100,
#                                                  250]},
#                          {'model': [RandomForestRegressor(max_depth=20,
#                                                           max_features=10,
#                                                           n_estimators=1000)],
#                           'model__max_depth': [5, 10, 20],
#                           'model__max_features': [10, 20, 30],
#                           'model__n_estimators': [100, 500, 1000]}],
#              scoring='neg_root_mean_squared_error')

# %%
## what is the best score
search.best_score_
# Out:
# -1.0571914103419555

# %%
## best parameter configuration
search.best_params_
# Out:
# {'model': RandomForestRegressor(max_depth=20, max_features=10, n_estimators=1000),
#  'model__max_depth': 20,
#  'model__max_features': 10,
#  'model__n_estimators': 1000}

# %%
## which model performed best
search.best_estimator_
# Out:
# Pipeline(steps=[('pre_process',
#                  ColumnTransformer(transformers=[('num', MinMaxScaler(),
#                                                   ['water_violation', 'IA',
#                                                    'BA', 'GDP', 'pov_perc',
#                                                    'Unemployment Rate',
#                                                    'traffic_vol', 'ownership',
#                                                    'residential_seg',
#                                                    'pop_to_phys',
#                                                    'air_pollution', 'uninsured',
#                                                    'exercise_opp',
#                                                    'income_ineq',
#                                                    'crime_violent',
#                                                    'high_sch_grad',
#                                                    'some_college',
#                                                    'soc_association',
#                                                    'perc_high_cost',
#                                                    'perc_overcrowding',
#                                                    'perc_plumb', 'lng_commute',
#                                                    'life_exp',
#                                                    'diab_prevalence',
#                                                    'food_access'])])),
#                 ('model',
#                  RandomForestRegressor(max_depth=20, max_features=10,
#                                        n_estimators=1000))])

# %%
## save model and parameter configurations into an object for further exploration below
rf_mod = search.best_estimator_

# %% [markdown]
# Although this is the final attempt for this outcome variables, let's look at how the model used the variables to make its prediction. Afterwards, we see what the test performance is and then continue on to the next outcome variables.

# %%
## let's shuffle the variables 50 times and see which variables the model relied on and which ones it relied the least on
vi = permutation_importance(rf_mod,train_X,train_y,n_repeats=50)

# %%
## organize shuffle results as a data frame 
vi_dat = pd.DataFrame(dict(variable=train_X.columns,
                           vi = vi['importances_mean'],
                           std = vi['importances_std']))

# %%
## generate intervals
vi_dat['low'] = vi_dat['vi'] - 2*vi_dat['std']
vi_dat['high'] = vi_dat['vi'] + 2*vi_dat['std']

# %%
# arrange dataframe in order from most to least important variables 
vi_dat = vi_dat.sort_values(by="vi",ascending=False).reset_index(drop=True)
vi_dat
# Out:
#              variable        vi       std       low      high
# 0   perc_overcrowding  0.187384  0.011584  0.164216  0.210552
# 1       high_sch_grad  0.100222  0.005230  0.089762  0.110682
# 2      perc_high_cost  0.097485  0.009226  0.079033  0.115937
# 3                  IA  0.095650  0.005496  0.084658  0.106642
# 4         traffic_vol  0.078026  0.004989  0.068047  0.088004
# 5   Unemployment Rate  0.077160  0.004931  0.067297  0.087023
# 6     soc_association  0.074688  0.004809  0.065071  0.084305
# 7         food_access  0.074500  0.006055  0.062390  0.086610
# 8       air_pollution  0.072861  0.005098  0.062664  0.083057
# 9                  BA  0.066795  0.005068  0.056659  0.076931
# 10           life_exp  0.058136  0.003506  0.051124  0.065148
# 11          uninsured  0.057814  0.004332  0.049150  0.066477
# 12       exercise_opp  0.049657  0.003092  0.043473  0.055842
# 13                GDP  0.046932  0.003058  0.040815  0.053049
# 14      crime_violent  0.046790  0.002660  0.041470  0.052110
# 15        lng_commute  0.042697  0.002461  0.037775  0.047619
# 16       some_college  0.036961  0.001625  0.033711  0.040210
# 17        pop_to_phys  0.036038  0.001627  0.032783  0.039292
# 18    diab_prevalence  0.035439  0.001642  0.032155  0.038722
# 19         perc_plumb  0.034280  0.002099  0.030081  0.038478
# 20        income_ineq  0.033611  0.001904  0.029803  0.037420
# 21           pov_perc  0.031813  0.002375  0.027062  0.036563
# 22    residential_seg  0.028871  0.001791  0.025289  0.032452
# 23    water_violation  0.003955  0.000463  0.003029  0.004881
# 24          ownership  0.002912  0.000324  0.002263  0.003560

# %%
## visualize the dataframe above using ggplot
(
    ggplot(vi_dat,
          aes(x="variable",y="vi")) +
    geom_col(alpha=.5) +
    geom_point() +
    geom_errorbar(aes(ymin="low",ymax="high"),width=.2) +
    theme_bw() +
    scale_x_discrete(limits=vi_dat.variable.tolist()) +
    coord_flip() +
    labs(y="Reduction in Root MSE",x="")
)
# Out:
# <ggplot: (8782821091274)>

# %% [markdown]
# When using a measure of disparity for the Hispanic population in a county as the outcome variable, the model relied on percent of housing with overcrowding; percentage of ninth-grade cohort that graduates in four years; the percent of households with high housing costs; the Native American population in a county; and the traffic volume in a county.

# %%
# Target specific features (top 5 important variables)
features = ['perc_overcrowding','high_sch_grad','perc_high_cost','IA','traffic_vol']

# Calculate the partial dependency
fig, ax = plt.subplots(figsize=(15, 7))
ax.set_title("Figure 4: Partial dependence of the oucome variable on the five most important features used by the random forest model")
display = plot_partial_dependence(
    rf_mod, train_X, features,n_cols=5,
    n_jobs=4, grid_resolution=30,ax=ax
)
fig.savefig('Part2_2.png')

# %% [markdown]
# These results are very interesting. Unlike the previous model, the scale of the y-axis extends from the negatives (which indictes lack of disparity because the share of COVID-19 cases is smaller than share of population) to past 0 indicating a presence of disparity because the share of COVID-19 cases is greater than the share of the population.
#
# Looking at the first variable, we see that an increase in the percent of households with overcrowding  is associated with a sharp and fast increase in disparity amongst the Hispanic community in a county. After a certain level of overcrowing we see a slight decline in disparity, but immediately after the value on the x-axis reaches -3, the disparity rises sharply again.
#
# Looking at the other plots, high_sch_grad; IA; and traffic_vol do not have a clear linear relationship with the outcome, but there seems to be a general increase in disparity as these variables increase. Conversely perc_high_cost has a negative relationship with the outcome variable .

# %% [markdown]
# ### Test Performance for outcome variable `disp_index_HI`

# %%
## make sure test does not include any NAs
test_X.isnull().sum()
# Out:
# water_violation      0
# BA                   0
# IA                   0
# GDP                  0
# pov_perc             0
# Unemployment Rate    0
# traffic_vol          0
# ownership            0
# residential_seg      0
# pop_to_phys          0
# air_pollution        0
# uninsured            0
# exercise_opp         0
# income_ineq          0
# crime_violent        0
# high_sch_grad        0
# some_college         0
# soc_association      0
# perc_high_cost       0
# perc_overcrowding    0
# perc_plumb           0
# lng_commute          0
# life_exp             0
# diab_prevalence      0
# food_access          0
# dtype: int64

# %%
## check for -inf
test_X.min()
# Out:
# water_violation       0.000000
# BA                    3.367296
# IA                    2.995732
# GDP                  10.900270
# pov_perc              4.900000
# Unemployment Rate     0.530628
# traffic_vol               -inf
# ownership             1.000000
# residential_seg       2.433584
# pop_to_phys           6.545687
# air_pollution         3.400000
# uninsured             0.040723
# exercise_opp          0.000000
# income_ineq           3.480230
# crime_violent         3.587608
# high_sch_grad         0.634000
# some_college          0.208518
# soc_association       0.000000
# perc_high_cost        0.046889
# perc_overcrowding    -6.835185
# perc_plumb                -inf
# lng_commute           0.076000
# life_exp             70.310741
# diab_prevalence       0.038000
# food_access           0.000840
# dtype: float64

# %%
## check for +inf
test_X.max()
# Out:
# water_violation       1.000000
# BA                   13.066893
# IA                    9.728956
# GDP                  18.938024
# pov_perc             42.500000
# Unemployment Rate     2.116256
# traffic_vol           7.652869
# ownership             2.000000
# residential_seg      64.311528
# pop_to_phys           9.896564
# air_pollution        13.300000
# uninsured             0.339399
# exercise_opp          1.000000
# income_ineq           8.473708
# crime_violent         7.312842
# high_sch_grad         0.981818
# some_college          0.903366
# soc_association      38.341721
# perc_high_cost        0.233259
# perc_overcrowding    -2.478629
# perc_plumb           -2.429477
# lng_commute           0.621000
# life_exp             86.061144
# diab_prevalence       0.310000
# food_access           0.317650
# dtype: float64

# %% [markdown]
# There are -inf values in the test data. These will be replaced with 0 because the predict function sklearn cannot deal with inf values.

# %%
## replace -inf values with 0
test_X=test_X.replace([-np.inf, np.nan], 0)

# %%
## confirm removal of -inf 
test_X.min()
# Out:
# water_violation       0.000000
# BA                    3.367296
# IA                    2.995732
# GDP                  10.900270
# pov_perc              4.900000
# Unemployment Rate     0.530628
# traffic_vol           0.000000
# ownership             1.000000
# residential_seg       2.433584
# pop_to_phys           6.545687
# air_pollution         3.400000
# uninsured             0.040723
# exercise_opp          0.000000
# income_ineq           3.480230
# crime_violent         3.587608
# high_sch_grad         0.634000
# some_college          0.208518
# soc_association       0.000000
# perc_high_cost        0.046889
# perc_overcrowding    -6.835185
# perc_plumb           -6.387961
# lng_commute           0.076000
# life_exp             70.310741
# diab_prevalence       0.038000
# food_access           0.000840
# dtype: float64

# %%
# Predict() method will use the best model out of the scan
pred_y = search.predict(test_X)

# %%
## performance using mean squared error
metric2=m.mean_squared_error(test_y,pred_y)

# %%
sqrt(metric2)
# Out:
# 1.078579858257841

# %% [markdown]
# Unlike the previous model (with a different outcome variable), this model performed better on the training data then the test data. The root mean squared error from the training set is 1.0571011062773121 and the root mean squared error from the test set is 1.0676377482939767. However these values are quite similar. Let us look at the r-squared value for the test set.

# %%
## performance using r2

# %%
m.r2_score(test_y,pred_y)
# Out:
# 0.008006531552207652

# %% [markdown]
# R-squared value is very low. The model is not doing well in predicting the outcome well; it is not explaining the variations in the outcome variable well. Let's see how this looks in a graph.

# %%
## change from array to dataframe for visualization
pred_y=pd.DataFrame(pred_y)

# %%
## reset index to 
train_y.reset_index(drop=True, inplace=True)

# %%
##combine pred_y and train_y into one dataframe and visualize
dat = pd.concat([pred_y, train_y], axis=1)

# %%
Part_2=   (
     ggplot(dat,aes(x='pred_y',y="train_y")) +
     geom_point(alpha=.5) +
      geom_abline(color="steelblue",size=1) +
       theme(figure_size=(7,4))+
       labs(title='Figure 3: Predicted outcome values vs. Actual outcome values', x='Predicted outcome values (test data)',
          y='Acutal outcome values (test data)' )+
       theme(dpi=100,
        legend_position="bottom",
        legend_direction="horizontal",
        legend_title_align="center",
        legend_box_spacing=0.4,
        legend_key=element_blank(),
        axis_line=element_line(size=1, colour="black"),
        panel_grid_major=element_line(colour="#d3d3d3"),
        panel_grid_minor=element_blank(),
        panel_border=element_blank(),
        panel_background=element_blank(),
        plot_title=element_text(size=11),
        text=element_text(family="Times New Roman", size=11),
        axis_text_x=element_text(colour="black", size=10),
        axis_text_y=element_text(colour="black", size=10),
  )
   )
Part_2.save("Part_2.png")
Part_2
# Out:
# <ggplot: (8782821181450)>

# %% [markdown]
# **Outcome Variable `disp_index_NA`: Diparity index tracking COVID-19 case disparity in Native American Population**

# %% [markdown]
# Now let's resplit the pre-processed data frame and attempt the modeling process of the outcome variable 'disp_index_NA'--index tracking disparity amongst the Native American population in a county.

# %%
##isolate outcome and features
y = df2[['disp_index_NA']]
##drop irrelevant columns when isolating features from outcome (including other outcome variables)
X = df2.drop(columns=['fips','state','county','cases_bl_pop', 'cases_na_pop',
       'cases_hi_pop', 'cases_aa_pop', 'bl_pop', 'na_pop', 'hi_pop', 'aa_pop',
                     'disp_index_BA','disp_index_NA','disp_index_HI','disp_index_AA'])
## also remove black population column because it was used to create the outcome variable
X=X.drop(columns=['IA'])

# %% [markdown]
# ### Modeling Pipeline

# %%
# (0) Split the data 
train_X, test_X, train_y, test_y = train_test_split(X,y,test_size=.25,random_state=123)

# (1) Set the folds index to ensure comparable samples
fold_generator = KFold(n_splits=5, shuffle=True,random_state=111)

# (2) Next specify the preprocessing steps
preprocess = ColumnTransformer(transformers=[('num', pp.MinMaxScaler(), ['water_violation', 'HI','BA', 'GDP', 'pov_perc', 'Unemployment Rate',
       'traffic_vol', 'ownership', 'residential_seg', 'pop_to_phys',
       'air_pollution', 'uninsured', 'exercise_opp', 'income_ineq',
       'crime_violent', 'high_sch_grad', 'some_college', 'soc_association',
       'perc_high_cost', 'perc_overcrowding', 'perc_plumb', 'lng_commute',
       'life_exp', 'diab_prevalence', 'food_access'])])


# (3) Next Let's create our model pipe (note for the model we leave none as a placeholder)
pipe = Pipeline(steps=[('pre_process', preprocess),
                       ('model',None)])


# (4) Specify the models and their repsective tuning parameters. 
# Note the naming convention here to reference the model key
search_space = [
    # Linear Model
    {'model' : [LM()]},
    
    # KNN with K tuning param
    {'model' : [KNN()],
     'model__n_neighbors':[1, 10, 25, 35, 50, 75, 100, 250]},
    
    # Random forest with the N Estimators tuning param
    {'model' : [RF()],
     'model__max_depth':[5, 10, 20],
     'model__n_estimators':[100,500,1000],
     'model__max_features': [10,20,30]},
]


# (5) Put it all together in the grid search
search = GridSearchCV(pipe, search_space, 
                      cv = fold_generator,
                      scoring='neg_root_mean_squared_error',
                      n_jobs=4)

# (6) Fit the model to the training data
search.fit(train_X,train_y)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=111, shuffle=True),
#              estimator=Pipeline(steps=[('pre_process',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          MinMaxScaler(),
#                                                                          ['water_violation',
#                                                                           'HI',
#                                                                           'BA',
#                                                                           'GDP',
#                                                                           'pov_perc',
#                                                                           'Unemployment '
#                                                                           'Rate',
#                                                                           'traffic_vol',
#                                                                           'ownership',
#                                                                           'residential_seg',
#                                                                           'pop_to_phys',
#                                                                           'air_pollution',
#                                                                           'uninsured',
#                                                                           'exercise_opp',
#                                                                           'income_ineq',
#                                                                           'crime_vi...
#                                                                           'food_access'])])),
#                                        ('model', None)]),
#              n_jobs=4,
#              param_grid=[{'model': [LinearRegression()]},
#                          {'model': [KNeighborsRegressor(n_neighbors=25)],
#                           'model__n_neighbors': [1, 10, 25, 35, 50, 75, 100,
#                                                  250]},
#                          {'model': [RandomForestRegressor()],
#                           'model__max_depth': [5, 10, 20],
#                           'model__max_features': [10, 20, 30],
#                           'model__n_estimators': [100, 500, 1000]}],
#              scoring='neg_root_mean_squared_error')

# %%
## what is the best score
search.best_score_
# Out:
# -0.379740031751039

# %%
## best parameter configuration
search.best_params_
# Out:
# {'model': KNeighborsRegressor(n_neighbors=25), 'model__n_neighbors': 25}

# %%
## which model performed best
search.best_estimator_
# Out:
# Pipeline(steps=[('pre_process',
#                  ColumnTransformer(transformers=[('num', MinMaxScaler(),
#                                                   ['water_violation', 'HI',
#                                                    'BA', 'GDP', 'pov_perc',
#                                                    'Unemployment Rate',
#                                                    'traffic_vol', 'ownership',
#                                                    'residential_seg',
#                                                    'pop_to_phys',
#                                                    'air_pollution', 'uninsured',
#                                                    'exercise_opp',
#                                                    'income_ineq',
#                                                    'crime_violent',
#                                                    'high_sch_grad',
#                                                    'some_college',
#                                                    'soc_association',
#                                                    'perc_high_cost',
#                                                    'perc_overcrowding',
#                                                    'perc_plumb', 'lng_commute',
#                                                    'life_exp',
#                                                    'diab_prevalence',
#                                                    'food_access'])])),
#                 ('model', KNeighborsRegressor(n_neighbors=25))])

# %%
## save model and parameter configurations into an object for further exploration below
rf_mod = search.best_estimator_

# %% [markdown]
# Although this is the final attempt for this outcome variables, let's look at how the model used the variables to make its prediction. Afterwards, we see what the test performance is and then continue on to the next outcome variables.

# %%
## let's shuffle the variables 50 times and see which variables the model relied on and which ones it relied the least on
vi = permutation_importance(rf_mod,train_X,train_y,n_repeats=50)

# %%
## organize shuffle results as a data frame 
vi_dat = pd.DataFrame(dict(variable=train_X.columns,
                           vi = vi['importances_mean'],
                           std = vi['importances_std']))

# %%
## generate intervals
vi_dat['low'] = vi_dat['vi'] - 2*vi_dat['std']
vi_dat['high'] = vi_dat['vi'] + 2*vi_dat['std']

# %%
# arrange dataframe in order from most to least important variables 
vi_dat = vi_dat.sort_values(by="vi",ascending=False).reset_index(drop=True)
vi_dat
# Out:
#              variable        vi       std       low      high
# 0           ownership  0.077838  0.030274  0.017291  0.138386
# 1     water_violation  0.043407  0.017870  0.007666  0.079148
# 2         food_access  0.003066  0.004494 -0.005922  0.012054
# 3          perc_plumb  0.002682  0.002695 -0.002707  0.008072
# 4         lng_commute  0.001909  0.005825 -0.009740  0.013558
# 5         pop_to_phys  0.001757  0.005420 -0.009083  0.012598
# 6                  HI  0.001179  0.003922 -0.006665  0.009024
# 7       air_pollution  0.000549  0.002144 -0.003738  0.004836
# 8       crime_violent  0.000351  0.002470 -0.004590  0.005291
# 9       high_sch_grad -0.001805  0.004063 -0.009931  0.006320
# 10    residential_seg -0.002517  0.003990 -0.010498  0.005464
# 11    soc_association -0.002702  0.003289 -0.009280  0.003876
# 12       exercise_opp -0.002757  0.006337 -0.015432  0.009917
# 13       some_college -0.002847  0.005504 -0.013855  0.008161
# 14  Unemployment Rate -0.002905  0.009769 -0.022443  0.016633
# 15     perc_high_cost -0.002937  0.002928 -0.008794  0.002919
# 16                GDP -0.003501  0.004645 -0.012792  0.005789
# 17        traffic_vol -0.003630  0.004214 -0.012058  0.004797
# 18    diab_prevalence -0.004229  0.002692 -0.009613  0.001155
# 19                 BA -0.006036  0.003649 -0.013334  0.001262
# 20          uninsured -0.007631  0.008741 -0.025114  0.009852
# 21  perc_overcrowding -0.008592  0.005721 -0.020035  0.002850
# 22        income_ineq -0.010467  0.008119 -0.026705  0.005770
# 23           life_exp -0.011505  0.006608 -0.024722  0.001711
# 24           pov_perc -0.012358  0.006373 -0.025104  0.000388

# %%
## visualize the dataframe above using ggplot
(
    ggplot(vi_dat,
          aes(x="variable",y="vi")) +
    geom_col(alpha=.5) +
    geom_point() +
    geom_errorbar(aes(ymin="low",ymax="high"),width=.2) +
    theme_bw() +
    scale_x_discrete(limits=vi_dat.variable.tolist()) +
    coord_flip() +
    labs(y="Reduction in Root MSE",x="")
)
# Out:
# <ggplot: (8782821698076)>

# %% [markdown]
# When using a measure of disparity for the Native American population in a county as the outcome variable, the model relied on housing ownership; presence of a water violation; food acess; percent of housing with plumbing issues; and the Hispanic population in a county. Water violation is a variable that hasn't appeared as among the most important variables in the previous models. It is also evident that some variables were extremely unimportant to the model--there are quite a few variables with a negative importance. This is probably an indication that leaving these variables out of the model may improve the model performance. Let's re-run this modeling pipeline after removing these irrelevant variables.

# %%
##isolate outcome and features
y = df2[['disp_index_NA']]
##drop irrelevant columns when isolating features from outcome (including other outcome variables)
X = df2.drop(columns=['fips','state','county','cases_bl_pop', 'cases_na_pop',
       'cases_hi_pop', 'cases_aa_pop', 'bl_pop', 'na_pop', 'hi_pop', 'aa_pop',
                     'disp_index_BA','disp_index_NA','disp_index_HI','disp_index_AA', 'life_exp','pov_perc',
                     'income_ineq', 'uninsured', 'perc_overcrowding', 'BA', 'Unemployment Rate','traffic_vol',
                     'diab_prevalence','exercise_opp','GDP','residential_seg','some_college','perc_high_cost',
                     'soc_association'])
## also remove black population column because it was used to create the outcome variable
X=X.drop(columns=['IA'])

# %% [markdown]
# ### Modeling Pipeline

# %%
# (0) Split the data 
train_X, test_X, train_y, test_y = train_test_split(X,y,test_size=.25,random_state=123)

# (1) Set the folds index to ensure comparable samples
fold_generator = KFold(n_splits=5, shuffle=True,random_state=111)

# (2) Next specify the preprocessing steps
preprocess = ColumnTransformer(transformers=[('num', pp.MinMaxScaler(), ['water_violation', 'HI',
      'ownership', 'pop_to_phys',
       'air_pollution', 
       'crime_violent', 'high_sch_grad',
       'perc_plumb', 'lng_commute', 'food_access'])])


# (3) Next Let's create our model pipe (note for the model we leave none as a placeholder)
pipe = Pipeline(steps=[('pre_process', preprocess),
                       ('model',None)])


# (4) Specify the models and their repsective tuning parameters. 
# Note the naming convention here to reference the model key
search_space = [
    # Linear Model
    {'model' : [LM()]},
    
    # KNN with K tuning param
    {'model' : [KNN()],
     'model__n_neighbors':[1, 10, 25, 35, 50, 75, 100, 250]},
    
    # Random forest with the N Estimators tuning param
    {'model' : [RF()],
     'model__max_depth':[5, 10, 20],
     'model__n_estimators':[100,500,1000],
     'model__max_features': [10,20,30]},
]


# (5) Put it all together in the grid search
search = GridSearchCV(pipe, search_space, 
                      cv = fold_generator,
                      scoring='neg_root_mean_squared_error',
                      n_jobs=4)

# (6) Fit the model to the training data
search.fit(train_X,train_y)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=111, shuffle=True),
#              estimator=Pipeline(steps=[('pre_process',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          MinMaxScaler(),
#                                                                          ['water_violation',
#                                                                           'HI',
#                                                                           'ownership',
#                                                                           'pop_to_phys',
#                                                                           'air_pollution',
#                                                                           'crime_violent',
#                                                                           'high_sch_grad',
#                                                                           'perc_plumb',
#                                                                           'lng_commute',
#                                                                           'food_access'])])),
#                                        ('model', None)]),
#              n_jobs=4,
#              param_grid=[{'model': [LinearRegression()]},
#                          {'model': [KNeighborsRegressor(n_neighbors=250)],
#                           'model__n_neighbors': [1, 10, 25, 35, 50, 75, 100,
#                                                  250]},
#                          {'model': [RandomForestRegressor()],
#                           'model__max_depth': [5, 10, 20],
#                           'model__max_features': [10, 20, 30],
#                           'model__n_estimators': [100, 500, 1000]}],
#              scoring='neg_root_mean_squared_error')

# %%
## what is the best score
search.best_score_
# Out:
# -0.3812277867707877

# %%
## best parameter configuration
search.best_params_
# Out:
# {'model': KNeighborsRegressor(n_neighbors=250), 'model__n_neighbors': 250}

# %%
## which model performed best
search.best_estimator_
# Out:
# Pipeline(steps=[('pre_process',
#                  ColumnTransformer(transformers=[('num', MinMaxScaler(),
#                                                   ['water_violation', 'HI',
#                                                    'ownership', 'pop_to_phys',
#                                                    'air_pollution',
#                                                    'crime_violent',
#                                                    'high_sch_grad',
#                                                    'perc_plumb', 'lng_commute',
#                                                    'food_access'])])),
#                 ('model', KNeighborsRegressor(n_neighbors=250))])

# %%
## save model and parameter configurations into an object for further exploration below
rf_mod = search.best_estimator_

# %% [markdown]
# Although this is the final attempt for this outcome variables, let's look at how the model used the variables to make its prediction. Afterwards, we see what the test performance is and then continue on to the next outcome variables.

# %%
## let's shuffle the variables 50 times and see which variables the model relied on and which ones it relied the least on
vi = permutation_importance(rf_mod,train_X,train_y,n_repeats=50)

# %%
## organize shuffle results as a data frame 
vi_dat = pd.DataFrame(dict(variable=train_X.columns,
                           vi = vi['importances_mean'],
                           std = vi['importances_std']))

# %%
## generate intervals
vi_dat['low'] = vi_dat['vi'] - 2*vi_dat['std']
vi_dat['high'] = vi_dat['vi'] + 2*vi_dat['std']

# %%
# arrange dataframe in order from most to least important variables 
vi_dat = vi_dat.sort_values(by="vi",ascending=False).reset_index(drop=True)
vi_dat
# Out:
#           variable        vi       std       low      high
# 0        ownership  0.002817  0.003218 -0.003619  0.009252
# 1               HI  0.001745  0.001250 -0.000755  0.004245
# 2    air_pollution  0.001409  0.001302 -0.001196  0.004013
# 3  water_violation  0.000977  0.001107 -0.001238  0.003191
# 4      lng_commute  0.000773  0.001083 -0.001393  0.002939
# 5    high_sch_grad  0.000397  0.000771 -0.001146  0.001939
# 6    crime_violent  0.000208  0.000501 -0.000795  0.001211
# 7      pop_to_phys -0.000091  0.000497 -0.001085  0.000902
# 8      food_access -0.000944  0.000492 -0.001929  0.000040
# 9       perc_plumb -0.001115  0.000635 -0.002386  0.000156

# %%
## visualize the dataframe above using ggplot
(
    ggplot(vi_dat,
          aes(x="variable",y="vi")) +
    geom_col(alpha=.5) +
    geom_point() +
    geom_errorbar(aes(ymin="low",ymax="high"),width=.2) +
    theme_bw() +
    scale_x_discrete(limits=vi_dat.variable.tolist()) +
    coord_flip() +
    labs(y="Reduction in Root MSE",x="")
)
# Out:
# <ggplot: (8782822021708)>

# %% [markdown]
# Even after removing the irrelevant variables' we see that the confidence intervals for the most important variables extends into negative values. Furthermore, the most important value, ownership, had a variance importance of about 0.2%--this is very small. It means that shuffling this variable 50 times reduced the mean error by 0.2%--it had little to no effect on th emeans squared error. As such it is difficult to draw any conclusions from this plot. This likely occured because there isnot much variation in the outcome variable. There were few COVID-19 cases for Native American populations reported in the New York Times data set.

# %%
# Target specific features (top 5 important variables)
features = ['ownership','water_violation','air_pollution','lng_commute','HI']

# Calculate the partial dependency
fig, ax = plt.subplots(figsize=(15, 7))
ax.set_title("Figure 6: Partial dependence of the oucome variable on the five most important features used by the random forest model")
display = plot_partial_dependence(
    rf_mod, train_X, features,n_cols=5,
    n_jobs=4, grid_resolution=30,ax=ax
)
##fig.savefig('Part3_2.png')

# %% [markdown]
# It looks like ownership, air_pollution, and lng_commute have a negative relationship with the outcome variable, while water_violation and HI have a negative relationship with the outcome variable.

# %% [markdown]
# ### Test Performance for outcome variable `disp_index_NA`

# %%
## make sure test does not include any NAs
test_X.isnull().sum()
# Out:
# water_violation    0
# HI                 0
# ownership          0
# pop_to_phys        0
# air_pollution      0
# crime_violent      0
# high_sch_grad      0
# perc_plumb         0
# lng_commute        0
# food_access        0
# dtype: int64

# %%
## check for -inf
test_X.min()
# Out:
# water_violation    0.000000
# HI                 4.700480
# ownership          1.000000
# pop_to_phys        6.545687
# air_pollution      3.400000
# crime_violent      3.587608
# high_sch_grad      0.634000
# perc_plumb             -inf
# lng_commute        0.076000
# food_access        0.000840
# dtype: float64

# %%
## check for +inf
test_X.max()
# Out:
# water_violation     1.000000
# HI                 12.764499
# ownership           2.000000
# pop_to_phys         9.896564
# air_pollution      13.300000
# crime_violent       7.312842
# high_sch_grad       0.981818
# perc_plumb         -2.429477
# lng_commute         0.621000
# food_access         0.317650
# dtype: float64

# %% [markdown]
# There are -inf values in the test data. These will be replaced with 0 because the predict function sklearn cannot deal with inf values.

# %%
## replace -inf values with 0
test_X=test_X.replace([-np.inf, np.nan], 0)

# %%
## confirm removal of -inf 
test_X.min()
# Out:
# water_violation    0.000000
# HI                 4.700480
# ownership          1.000000
# pop_to_phys        6.545687
# air_pollution      3.400000
# crime_violent      3.587608
# high_sch_grad      0.634000
# perc_plumb        -6.387961
# lng_commute        0.076000
# food_access        0.000840
# dtype: float64

# %%
# Predict() method will use the best model out of the scan
pred_y = search.predict(test_X)

# %%
## performance using mean squared error
metric3=m.mean_squared_error(test_y,pred_y)

# %%
sqrt(metric3)
# Out:
# 0.16929599942533174

# %% [markdown]
# The performance on the training data was better than in the test data. The training data had a mean squared error of 0.379740031751039 while the test data has a mean squared error of 0.17577103631841687.

# %%
## performance using r2

# %%
m.r2_score(test_y,pred_y)
# Out:
# -0.06452813835219606

# %% [markdown]
# R-squared value is very low.

# %%
## change from array to dataframe for visualization
pred_y=pd.DataFrame(pred_y)

# %%
## reset index to combine pred_y and train_y into one dataframe and visualize
train_y.reset_index(drop=True, inplace=True)

# %%
dat = pd.concat([pred_y, train_y], axis=1)

# %%
Part_3=   (
     ggplot(dat,aes(x='pred_y',y="train_y")) +
     geom_point(alpha=.5) +
      geom_abline(color="steelblue",size=1) +
       theme(figure_size=(7,4))+
       labs(title='Figure 5: Predicted outcome values vs. Actual outcome values', x='Predicted outcome values (test data)',
          y='Acutal outcome values (test data)' )+
       theme(dpi=100,
        legend_position="bottom",
        legend_direction="horizontal",
        legend_title_align="center",
        legend_box_spacing=0.4,
        legend_key=element_blank(),
        axis_line=element_line(size=1, colour="black"),
        panel_grid_major=element_line(colour="#d3d3d3"),
        panel_grid_minor=element_blank(),
        panel_border=element_blank(),
        panel_background=element_blank(),
        plot_title=element_text(size=11),
        text=element_text(family="Times New Roman", size=11),
        axis_text_x=element_text(colour="black", size=10),
        axis_text_y=element_text(colour="black", size=10),
  )
   )
Part_3.save("Part_3.png")
Part_3
# Out:
# <ggplot: (8782821997641)>

# %% [markdown]
# **Outcome Variable `disp_index_AA`: Diparity index tracking COVID-19 case disparity in Asian American Population**

# %% [markdown]
# Now let's resplit the pre-processed data frame and attempt the modeling process of the outcome variable 'disp_index_AA'--index tracking disparity amongst the Asian American population in a county.

# %%
##isolate outcome and features
y = df2[['disp_index_AA']]
##drop irrelevant columns when isolating features from outcome (including other outcome variables)
X = df2.drop(columns=['fips','state','county','cases_bl_pop', 'cases_na_pop',
       'cases_hi_pop', 'cases_aa_pop', 'bl_pop', 'na_pop', 'hi_pop', 'aa_pop',
                     'disp_index_BA','disp_index_NA','disp_index_HI','disp_index_AA'])

# %% [markdown]
# ### Modeling Pipeline

# %%
# (0) Split the data 
train_X, test_X, train_y, test_y = train_test_split(X,y,test_size=.25,random_state=123)

# (1) Set the folds index to ensure comparable samples
fold_generator = KFold(n_splits=5, shuffle=True,random_state=111)

# (2) Next specify the preprocessing steps
preprocess = ColumnTransformer(transformers=[('num', pp.MinMaxScaler(), ['water_violation', 'IA','HI','BA', 'GDP', 'pov_perc', 'Unemployment Rate',
       'traffic_vol', 'ownership', 'residential_seg', 'pop_to_phys',
       'air_pollution', 'uninsured', 'exercise_opp', 'income_ineq',
       'crime_violent', 'high_sch_grad', 'some_college', 'soc_association',
       'perc_high_cost', 'perc_overcrowding', 'perc_plumb', 'lng_commute',
       'life_exp', 'diab_prevalence', 'food_access'])])


# (3) Next Let's create our model pipe (note for the model we leave none as a placeholder)
pipe = Pipeline(steps=[('pre_process', preprocess),
                       ('model',None)])


# (4) Specify the models and their repsective tuning parameters. 
# Note the naming convention here to reference the model key
search_space = [
    # Linear Model
    {'model' : [LM()]},
    
    # KNN with K tuning param
    {'model' : [KNN()],
     'model__n_neighbors':[1, 10, 25, 35, 50, 75, 100, 250]},
    
    # Random forest with the N Estimators tuning param
    {'model' : [RF()],
     'model__max_depth':[5, 10, 20],
     'model__n_estimators':[100,500,1000],
     'model__max_features': [10,20,30]},
]


# (5) Put it all together in the grid search
search = GridSearchCV(pipe, search_space, 
                      cv = fold_generator,
                      scoring='neg_root_mean_squared_error',
                      n_jobs=4)

# (6) Fit the model to the training data
search.fit(train_X,train_y)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=111, shuffle=True),
#              estimator=Pipeline(steps=[('pre_process',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          MinMaxScaler(),
#                                                                          ['water_violation',
#                                                                           'IA',
#                                                                           'HI',
#                                                                           'BA',
#                                                                           'GDP',
#                                                                           'pov_perc',
#                                                                           'Unemployment '
#                                                                           'Rate',
#                                                                           'traffic_vol',
#                                                                           'ownership',
#                                                                           'residential_seg',
#                                                                           'pop_to_phys',
#                                                                           'air_pollution',
#                                                                           'uninsured',
#                                                                           'exercise_opp',
#                                                                           'income_ineq',
#                                                                           'cri...
#              n_jobs=4,
#              param_grid=[{'model': [LinearRegression()]},
#                          {'model': [KNeighborsRegressor()],
#                           'model__n_neighbors': [1, 10, 25, 35, 50, 75, 100,
#                                                  250]},
#                          {'model': [RandomForestRegressor(max_depth=20,
#                                                           max_features=10,
#                                                           n_estimators=500)],
#                           'model__max_depth': [5, 10, 20],
#                           'model__max_features': [10, 20, 30],
#                           'model__n_estimators': [100, 500, 1000]}],
#              scoring='neg_root_mean_squared_error')

# %%
## what is the best score
search.best_score_
# Out:
# -0.2872429344835891

# %%
## best parameter configuration
search.best_params_
# Out:
# {'model': RandomForestRegressor(max_depth=20, max_features=10, n_estimators=500),
#  'model__max_depth': 20,
#  'model__max_features': 10,
#  'model__n_estimators': 500}

# %%
## which model performed best
search.best_estimator_
# Out:
# Pipeline(steps=[('pre_process',
#                  ColumnTransformer(transformers=[('num', MinMaxScaler(),
#                                                   ['water_violation', 'IA',
#                                                    'HI', 'BA', 'GDP',
#                                                    'pov_perc',
#                                                    'Unemployment Rate',
#                                                    'traffic_vol', 'ownership',
#                                                    'residential_seg',
#                                                    'pop_to_phys',
#                                                    'air_pollution', 'uninsured',
#                                                    'exercise_opp',
#                                                    'income_ineq',
#                                                    'crime_violent',
#                                                    'high_sch_grad',
#                                                    'some_college',
#                                                    'soc_association',
#                                                    'perc_high_cost',
#                                                    'perc_overcrowding',
#                                                    'perc_plumb', 'lng_commute',
#                                                    'life_exp',
#                                                    'diab_prevalence',
#                                                    'food_access'])])),
#                 ('model',
#                  RandomForestRegressor(max_depth=20, max_features=10,
#                                        n_estimators=500))])

# %%
## save model and parameter configurations into an object for further exploration below
rf_mod = search.best_estimator_

# %% [markdown]
# Although this is the final attempt for this outcome variables, let's look at how the model used the variables to make its prediction. Afterwards, we see what the test performance is and then continue on to the next outcome variables.

# %%
## let's shuffle the variables 50 times and see which variables the model relied on and which ones it relied the least on
vi = permutation_importance(rf_mod,train_X,train_y,n_repeats=50)

# %%
## organize shuffle results as a data frame 
vi_dat = pd.DataFrame(dict(variable=train_X.columns,
                           vi = vi['importances_mean'],
                           std = vi['importances_std']))

# %%
## generate intervals
vi_dat['low'] = vi_dat['vi'] - 2*vi_dat['std']
vi_dat['high'] = vi_dat['vi'] + 2*vi_dat['std']

# %%
# arrange dataframe in order from most to least important variables 
vi_dat = vi_dat.sort_values(by="vi",ascending=False).reset_index(drop=True)
vi_dat
# Out:
#              variable        vi       std       low      high
# 0            life_exp  0.170495  0.041564  0.087366  0.253623
# 1                 GDP  0.142209  0.029724  0.082761  0.201657
# 2        some_college  0.133077  0.036823  0.059430  0.206723
# 3                  HI  0.100765  0.018571  0.063623  0.137908
# 4     diab_prevalence  0.099003  0.036183  0.026637  0.171369
# 5        exercise_opp  0.083091  0.019031  0.045029  0.121153
# 6                  BA  0.079583  0.008970  0.061643  0.097522
# 7         traffic_vol  0.059165  0.006389  0.046387  0.071944
# 8          perc_plumb  0.047515  0.011039  0.025438  0.069593
# 9   Unemployment Rate  0.038774  0.006153  0.026468  0.051081
# 10        lng_commute  0.032243  0.003862  0.024519  0.039967
# 11           pov_perc  0.029944  0.005158  0.019629  0.040259
# 12        pop_to_phys  0.028337  0.004243  0.019851  0.036823
# 13     perc_high_cost  0.027798  0.005976  0.015846  0.039750
# 14                 IA  0.025260  0.004542  0.016175  0.034345
# 15        income_ineq  0.019454  0.004558  0.010339  0.028570
# 16      crime_violent  0.018423  0.002728  0.012967  0.023880
# 17        food_access  0.017805  0.001429  0.014946  0.020663
# 18    soc_association  0.017122  0.002516  0.012091  0.022154
# 19  perc_overcrowding  0.015800  0.002415  0.010970  0.020629
# 20      air_pollution  0.015744  0.004086  0.007571  0.023917
# 21          uninsured  0.011869  0.001243  0.009383  0.014355
# 22      high_sch_grad  0.011566  0.001416  0.008735  0.014397
# 23    residential_seg  0.006381  0.001057  0.004267  0.008496
# 24          ownership  0.002138  0.001061  0.000016  0.004260
# 25    water_violation  0.001873  0.001186 -0.000500  0.004245

# %%
## visualize the dataframe above using ggplot
(
    ggplot(vi_dat,
          aes(x="variable",y="vi")) +
    geom_col(alpha=.5) +
    geom_point() +
    geom_errorbar(aes(ymin="low",ymax="high"),width=.2) +
    theme_bw() +
    scale_x_discrete(limits=vi_dat.variable.tolist()) +
    coord_flip() +
    labs(y="Reduction in Root MSE",x="")
)
# Out:
# <ggplot: (8782828426388)>

# %% [markdown]
# When using a measure of disparity for the Asian American population in a county as the outcome variable, the model relied on life expectancy; gdp; number of adults with some college education; hispanic population in a county; and diabetes prevalence.

# %%
# Target specific features (top 5 important variables)
features = ['life_exp','GDP','some_college','diab_prevalence','HI']

# Calculate the partial dependency
fig, ax = plt.subplots(figsize=(15, 7))
ax.set_title("Figure 7: Partial dependence of the oucome variable on the five most important features used by the random forest model")
display = plot_partial_dependence(
    rf_mod, train_X, features,n_cols=5,
    n_jobs=4, grid_resolution=30,ax=ax
)
fig.savefig('Part4_2.png')

# %% [markdown]
# The feature variables have a very non-linear relationship with the outcome variables. The outcome variable seems to decrease with an increase in life expectancy. Generally, higher GDP is associated with more parity, but there seems to be a point in the middle of the plot where an increase in GDP leads to less parity. Generally speaking, an increase in some_college leads to an increase in parity. This seems to be the case with HI, aswell. Lastly, and increase in diab_prevalence leads to a decrease in parity.

# %% [markdown]
# ### Test Performance for outcome variable `disp_index_AA`

# %%
## make sure test does not include any NAs
test_X.isnull().sum()
# Out:
# water_violation      0
# BA                   0
# IA                   0
# HI                   0
# GDP                  0
# pov_perc             0
# Unemployment Rate    0
# traffic_vol          0
# ownership            0
# residential_seg      0
# pop_to_phys          0
# air_pollution        0
# uninsured            0
# exercise_opp         0
# income_ineq          0
# crime_violent        0
# high_sch_grad        0
# some_college         0
# soc_association      0
# perc_high_cost       0
# perc_overcrowding    0
# perc_plumb           0
# lng_commute          0
# life_exp             0
# diab_prevalence      0
# food_access          0
# dtype: int64

# %%
## check for -inf
test_X.min()
# Out:
# water_violation       0.000000
# BA                    3.367296
# IA                    2.995732
# HI                    4.700480
# GDP                  10.900270
# pov_perc              4.900000
# Unemployment Rate     0.530628
# traffic_vol               -inf
# ownership             1.000000
# residential_seg       2.433584
# pop_to_phys           6.545687
# air_pollution         3.400000
# uninsured             0.040723
# exercise_opp          0.000000
# income_ineq           3.480230
# crime_violent         3.587608
# high_sch_grad         0.634000
# some_college          0.208518
# soc_association       0.000000
# perc_high_cost        0.046889
# perc_overcrowding    -6.835185
# perc_plumb                -inf
# lng_commute           0.076000
# life_exp             70.310741
# diab_prevalence       0.038000
# food_access           0.000840
# dtype: float64

# %%
## check for +inf
test_X.max()
# Out:
# water_violation       1.000000
# BA                   13.066893
# IA                    9.728956
# HI                   12.764499
# GDP                  18.938024
# pov_perc             42.500000
# Unemployment Rate     2.116256
# traffic_vol           7.652869
# ownership             2.000000
# residential_seg      64.311528
# pop_to_phys           9.896564
# air_pollution        13.300000
# uninsured             0.339399
# exercise_opp          1.000000
# income_ineq           8.473708
# crime_violent         7.312842
# high_sch_grad         0.981818
# some_college          0.903366
# soc_association      38.341721
# perc_high_cost        0.233259
# perc_overcrowding    -2.478629
# perc_plumb           -2.429477
# lng_commute           0.621000
# life_exp             86.061144
# diab_prevalence       0.310000
# food_access           0.317650
# dtype: float64

# %% [markdown]
# There are -inf values in the test data. These will be replaced with 0 because the predict function sklearn cannot deal with inf values.

# %%
## replace -inf values with 0
test_X=test_X.replace([-np.inf, np.nan], 0)

# %%
## confirm removal of -inf 
test_X.min()
# Out:
# water_violation       0.000000
# BA                    3.367296
# IA                    2.995732
# HI                    4.700480
# GDP                  10.900270
# pov_perc              4.900000
# Unemployment Rate     0.530628
# traffic_vol           0.000000
# ownership             1.000000
# residential_seg       2.433584
# pop_to_phys           6.545687
# air_pollution         3.400000
# uninsured             0.040723
# exercise_opp          0.000000
# income_ineq           3.480230
# crime_violent         3.587608
# high_sch_grad         0.634000
# some_college          0.208518
# soc_association       0.000000
# perc_high_cost        0.046889
# perc_overcrowding    -6.835185
# perc_plumb           -6.387961
# lng_commute           0.076000
# life_exp             70.310741
# diab_prevalence       0.038000
# food_access           0.000840
# dtype: float64

# %%
# Predict() method will use the best model out of the scan
pred_y = search.predict(test_X)

# %%
## performance using mean squared error
metric4=m.mean_squared_error(test_y,pred_y)

# %%
sqrt(metric4)
# Out:
# 0.3243058599645539

# %%
metric4
# Out:
# 0.10517429080734884

# %% [markdown]
# The mean squared error is lower in the training set (i.e., 0.28705602138046993) than in the test set (0.3224436831238736.)

# %%
## performance using r2

# %%
m.r2_score(test_y,pred_y)
# Out:
# 0.16097519586901154

# %% [markdown]
# R-squared value is very low.

# %%
## change from array to dataframe for visualization
pred_y=pd.DataFrame(pred_y)

# %%
## reset index to combine pred_y and train_y into one dataframe and visualize
train_y.reset_index(drop=True, inplace=True)

# %%
dat = pd.concat([pred_y, train_y], axis=1)

# %%
Part_4=   (
     ggplot(dat,aes(x='pred_y',y="train_y")) +
     geom_point(alpha=.5) +
      geom_abline(color="steelblue",size=1) +
       theme(figure_size=(7,4))+
       labs(title='Figure 6: Predicted outcome values vs. Actual outcome values', x='Predicted outcome values (test data)',
          y='Acutal outcome values (test data)' )+
       theme(dpi=100,
        legend_position="bottom",
        legend_direction="horizontal",
        legend_title_align="center",
        legend_box_spacing=0.4,
        legend_key=element_blank(),
        axis_line=element_line(size=1, colour="black"),
        panel_grid_major=element_line(colour="#d3d3d3"),
        panel_grid_minor=element_blank(),
        panel_border=element_blank(),
        panel_background=element_blank(),
        plot_title=element_text(size=11),
        text=element_text(family="Times New Roman", size=11),
        axis_text_x=element_text(colour="black", size=10),
        axis_text_y=element_text(colour="black", size=10),
  )
   )
Part_4.save("Part_4.png")
Part_4
# Out:
# <ggplot: (8782822044167)>
